# %%
import osmnx as ox

# %%
import geopandas as gpd

# %% [markdown]
# Uses nominatim to geocode and find places
# - https://nominatim.openstreetmap.org/ui/search.html

# %%
# find a place
place_name = 'Culver City, California'

# %%
# get it
graph = ox.graph_from_place(place_name)

# %%
# plot it
ox.plot_graph(graph)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x22fe04e96a0>)

# %%
# convert this graph, networkx, to geodataframe
# it has two objects, nodes and edges
nodes, edges = ox.graph_to_gdfs(graph)

# %%
nodes.head()
# Out:
#                     y           x       osmid highway  ref  \
# 3701497859  33.988565 -118.380098  3701497859     NaN  NaN
# 307150853   33.988316 -118.396647   307150853     NaN  NaN
# 3701497861  33.988569 -118.380291  3701497861     NaN  NaN
# 3633168396  34.006881 -118.388679  3633168396     NaN  NaN
# 123650067   34.017054 -118.375017   123650067     NaN  NaN
#
#                                geometry
# 3701497859  POINT (-118.38010 33.98857)
# 307150853   POINT (-118.39665 33.98832)
# 3701497861  POINT (-118.38029 33.98857)
# 3633168396  POINT (-118.38868 34.00688)
# 123650067   POINT (-118.37502 34.01705)

# %%
edges.head()
# Out:
#                     osmid                 highway   service  oneway   length  \
# 0               366163182                 service  driveway   False   17.800
# 1  [366163186, 366163182]                 service  driveway   False  252.609
# 2               366163184                 service  driveway   False  104.367
# 3                56181716                 service     alley   False   61.081
# 4    [56181717, 13333159]  [residential, service]     alley   False  154.982
#
#                                             geometry           name access  \
# 0  LINESTRING (-118.38010 33.98857, -118.38029 33...            NaN    NaN
# 1  LINESTRING (-118.38010 33.98857, -118.37998 33...            NaN    NaN
# 2  LINESTRING (-118.38010 33.98857, -118.38010 33...            NaN    NaN
# 3  LINESTRING (-118.39665 33.98832, -118.39599 33...            NaN    NaN
# 4  LINESTRING (-118.39665 33.98832, -118.39661 33...  Corryne Place    NaN
#
#   lanes maxspeed  ref bridge tunnel junction           u           v  key
# 0   NaN      NaN  NaN    NaN    NaN      NaN  3701497859  3701497861    0
# 1   NaN      NaN  NaN    NaN    NaN      NaN  3701497859  3701497849    0
# 2   NaN      NaN  NaN    NaN    NaN      NaN  3701497859  3701497849    1
# 3   NaN      NaN  NaN    NaN    NaN      NaN   307150853   705015370    0
# 4   NaN      NaN  NaN    NaN    NaN      NaN   307150853   705015370    1

# %%
# get the place polygon
area = ox.geocode_to_gdf(place_name)

# %%
area
# Out:
#                                             geometry  \
# 0  POLYGON ((-118.44838 33.99334, -118.44716 33.9...
#
#                                           place_name  bbox_north  bbox_south  \
# 0  Culver City, Los Angeles County, California, U...   34.035086   33.976867
#
#     bbox_east   bbox_west
# 0 -118.369595 -118.448377

# %%
area.plot()

# %%
buildings = ox.footprints_from_place(place_name)

# %%
type(buildings)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
buildings.sample(3)
# Out:
#                                                        nodes amenity  \
# 422079220  [4218082389, 4218082435, 4218082412, 421808242...     NaN
# 421438361  [4211967198, 4211967292, 4211967303, 421196729...     NaN
# 439267153  [4368974081, 4368974053, 4368974012, 436897405...     NaN
#
#              building   ele height lacounty:ain lacounty:bld_id start_date  \
# 422079220       house  16.7    5.1   4215020015    438479823355       1952
# 421438361       house  15.8    4.4   4231023020    430580820764       1925
# 439267153  commercial  24.9    3.8   4208022001    436661828207       1963
#
#                                                     geometry building:units  \
# 422079220  POLYGON ((-118.40653 34.00205, -118.40643 34.0...              1
# 421438361  POLYGON ((-118.43250 33.99475, -118.43251 33.9...              1
# 439267153  POLYGON ((-118.41247 34.01539, -118.41241 34.0...              1
#
#            ... payment:visa denomination religion service_times members type  \
# 422079220  ...          NaN          NaN      NaN           NaN     NaN  NaN
# 421438361  ...          NaN          NaN      NaN           NaN     NaN  NaN
# 439267153  ...          NaN          NaN      NaN           NaN     NaN  NaN
#
#           gnis:county_id gnis:created gnis:feature_id gnis:state_id
# 422079220            NaN          NaN             NaN           NaN
# 421438361            NaN          NaN             NaN           NaN
# 439267153            NaN          NaN             NaN           NaN
#
# [3 rows x 89 columns]

# %% [markdown]
# Points of interest
# - https://osmnx.readthedocs.io/en/stable/osmnx.html#module-osmnx.pois
#
# List of tags, or "amenities"
# - https://wiki.openstreetmap.org/wiki/Key:amenity

# %%
# retrieve restaurants
restaurants = ox.pois_from_place(place_name, tags = {'amenity': ['restaurant']})

# %%
len(restaurants)
# Out:
# 27

# %% [markdown]
# ## Plotting all this data

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(20,20))

# plot the area polygon
area.plot(ax=ax, facecolor='gainsboro')

# plot the street edges
edges.plot(ax=ax, edgecolor='gray', linewidth=0.5, alpha=0.7)

# plot building footprints
buildings.plot(ax=ax)

# plot restaurants
restaurants.plot(ax=ax,color='red',markersize=50)

# %%
# neighborhoods or boroughs


gdf = ox.geocode_to_gdf('Los Angeles, Los Angeles, California, USA')

# %%
# get the boundary polygon for manhattan, project it, and plot it
city = ox.geocode_to_gdf('Los Angeles, California, USA')

# %%
city_proj = ox.project_gdf(city)
ax = city_proj.plot(fc='gray', ec='none',figsize=(10,10))
# ax = ax.axis('off')

# %%
# define a bounding box in Culver City
north, south, east, west = 34.03, 33.99, -118.37, -118.42

# create network from that bounding box
G = ox.graph_from_bbox(north, south, east, west)
fig, ax = ox.plot_graph(G)

# %%
ox.plot_graph_folium(G, edge_color='r')

# %%
# define a point at UCLA
location_point = (34.069624774724886, -118.44500631093979)

# create network from point, inside bounding box of N, S, E, W each 750m from point
G = ox.graph_from_point(location_point, dist=750,
                        dist_type='bbox', network_type='all') # try "drive" and "walk"
fig, ax = ox.plot_graph(G)

# %%
ox.plot_graph_folium(G,  edge_linewidth=1, edge_color='r')
# ox.plot_graph_folium(G)

# %%
ox.basic_stats(G)

# %%
# same point again, but create network only of nodes within 750m along the network from point
G = ox.graph_from_point(location_point, dist=750, 
                        dist_type='network')
fig, ax = ox.plot_graph(G, node_color='r')

# %%
# network from address, including only nodes within 1km along the network from the address
G = ox.graph_from_address(address='UCLA, Los Angeles, CA', dist=1000,
                          dist_type='network', network_type='all')

fig, ax = ox.plot_graph(G, node_color='r')

# %%
# %%time
gdf = ox.footprints.footprints_from_place(place='UCLA, California, USA')
gdf_proj = ox.project_gdf(gdf)
fig, ax = ox.plot_footprints(gdf_proj)
# Image(fp, height=size, width=size)

# %%
fig, ax = ox.plot_graph(G,
    ax=None,               #optionally draw on pre-existing axis
    figsize=(8, 8),        #figure size to create if ax is None
    bgcolor="#111111",     #background color of the plot
    node_color="w",        #color of the nodes
    node_size=15,          #size of the nodes: if 0, skip plotting them
    node_alpha=None,       #opacity of the nodes
    node_edgecolor="none", #color of the nodes' markers' borders
    node_zorder=1,         #zorder to plot nodes: edges are always 1, so set node_zorder=0 to plot nodes below edges
    edge_color="#999999",  #color of the edges
    edge_linewidth=1,      #width of the edges: if 0, skip plotting them
    edge_alpha=None,       #opacity of the edges
    show=True,             #if True, call pyplot.show() to show the figure
    close=False,           #if True, call pyplot.close() to close the figure: useful if plotting/saving many in a loop
    save=False,            #if True, save figure to disk at filepath
    filepath=None,         #if save is True, the path to the file
    dpi=300,               #if save is True, the resolution of saved file
    bbox=None)             #bounding box to constrain plot: if None, will calculate from spatial extents of graphＢ

# %%
# get everything tagged amenity,
# and everything with landuse = retail or commercial,
# and everything with highway = bus_stop
tags = {'amenity' : True,
#         'landuse' : ['retail', 'commercial'],
#         'highway' : 'bus_stop'
       }
poi = ox.pois_from_place('Culver City, California, USA', tags)
poi.shape

# %%
poi.head()

# %%
poi.amenity.unique()

# %%
poi.groupby(['amenity']).count()['osmid'].reset_index(name='count').sort_values(['count'], ascending=False)

# %%
poi[poi.amenity=='school']

# %%
poi[poi.amenity=='school'].plot(figsize=(10,10))

# %%
# elevation. street nodes susceptible to flooding?
