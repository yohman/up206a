# %% [markdown]
# ## Census Data
#
# Use the censusdata module to import census data
#
# https://pypi.org/project/CensusData/

# %%
# pip install censusdata

# %%
import pandas as pd
import censusdata
# from tabulate import tabulate

# %% [markdown]
# ## Understanding the Census Bureau labyrinth
# Learn about the data:
# https://www.census.gov/programs-surveys/acs/technical-documentation/table-shells.html
#
# Search for data tables:
# https://data.census.gov/cedsci/
#
# Here are some of the main tables of interest:
#
# Population sizes:
#
# * Total Population: B01001e1
# * Population by Age and Sex: B01001*
# * Population by Household Incomes: B19001*
# * Population by Education Level: B15003*
# * Population by Race: B02001*
# * Population by Hispanic Ethnicity: B03003*
# * Population by Race & Hispanic Ethnicity: B03002*
# * Population by Household Type: B11001e*
#
# Summary Statistics:
#
# * Median Household Income: B19013e1
# * Aggregate Household Income:  B19025e1
# * Per Capita Income: B19301e1
# * Median Age: B01002e1
#
# For this workshop, let's work with "Population by race," or, in census lingo, Table ID B02001

# %%
# command to print the metadata about a specific census table
censusdata.printtable(censusdata.censustable('acs5',2018,'B02001'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B02001_001E  | RACE                           | !! Estimate Total                                        | int
# B02001_002E  | RACE                           | !! !! Estimate Total White alone                         | int
# B02001_003E  | RACE                           | !! !! Estimate Total Black or African American alone     | int
# B02001_004E  | RACE                           | !! !! Estimate Total American Indian and Alaska Native a | int
# B02001_005E  | RACE                           | !! !! Estimate Total Asian alone                         | int
# B02001_006E  | RACE                           | !! !! Estimate Total Native Hawaiian and Other Pacific I | int
# B02001_007E  | RACE                           | !! !! Estimate Total Some other race alone               | int
# B02001_008E  | RACE                           | !! !! Estimate Total Two or more races                   | int
# B02001_009E  | RACE                           | !! !! !! Estimate Total Two or more races Two races incl | int
# B02001_010E  | RACE                           | !! !! !! Estimate Total Two or more races Two races excl | int
# -------------------------------------------------------------------------------------------------------------------

# %%
# grab race columns by county
df_counties = censusdata.download('acs5', 
           2018,
           censusdata.censusgeo([('state', '06'), ('county', '*')]),
           ['B02001_001E','B02001_002E','B02001_003E','B02001_004E','B02001_005E','B02001_006E','B02001_007E','B02001_008E'])

# %%
df_counties.head()
# Out:
#                                                     B02001_001E  B02001_002E  \
# Lake County, California: Summary level: 050, st...        64148        49463
# Mariposa County, California: Summary level: 050...        17540        15579
# Yuba County, California: Summary level: 050, st...        75493        56344
# Contra Costa County, California: Summary level:...      1133247       648325
# Lassen County, California: Summary level: 050, ...        31185        25672
#
#                                                     B02001_003E  B02001_004E  \
# Lake County, California: Summary level: 050, st...         1562         2426
# Mariposa County, California: Summary level: 050...          166          397
# Yuba County, California: Summary level: 050, st...         2432         1079
# Contra Costa County, California: Summary level:...        97333         5529
# Lassen County, California: Summary level: 050, ...         2738          877
#
#                                                     B02001_005E  B02001_006E  \
# Lake County, California: Summary level: 050, st...          661           30
# Mariposa County, California: Summary level: 050...          243           54
# Yuba County, California: Summary level: 050, st...         5104          343
# Contra Costa County, California: Summary level:...       185065         5585
# Lassen County, California: Summary level: 050, ...          437          205
#
#                                                     B02001_007E  B02001_008E
# Lake County, California: Summary level: 050, st...         8048         1958
# Mariposa County, California: Summary level: 050...          396          705
# Yuba County, California: Summary level: 050, st...         4126         6065
# Contra Costa County, California: Summary level:...       112976        78434
# Lassen County, California: Summary level: 050, ...          590          666

# %%
# grab race columns by tracts
df_tracts = censusdata.download('acs5', 
           2018,
           censusdata.censusgeo([('state', '06'), ('county', '037'), ('tract', '*')]),
           ['B02001_001E','B02001_002E','B02001_003E','B02001_004E','B02001_005E','B02001_006E','B02001_007E','B02001_008E'])

# %%
df_tracts.head()
# Out:
#                                                     B02001_001E  B02001_002E  \
# Census Tract 5433.21, Los Angeles County, Calif...         5619          902
# Census Tract 5435.02, Los Angeles County, Calif...         4424         1493
# Census Tract 5501, Los Angeles County, Californ...         7441         3457
# Census Tract 5505, Los Angeles County, Californ...         8192         5124
# Census Tract 5510, Los Angeles County, Californ...         7311         3948
#
#                                                     B02001_003E  B02001_004E  \
# Census Tract 5433.21, Los Angeles County, Calif...         3363           47
# Census Tract 5435.02, Los Angeles County, Calif...          123           34
# Census Tract 5501, Los Angeles County, Californ...          330            0
# Census Tract 5505, Los Angeles County, Californ...           75          184
# Census Tract 5510, Los Angeles County, Californ...          177           70
#
#                                                     B02001_005E  B02001_006E  \
# Census Tract 5433.21, Los Angeles County, Calif...          644           15
# Census Tract 5435.02, Los Angeles County, Calif...         1174            0
# Census Tract 5501, Los Angeles County, Californ...          616            0
# Census Tract 5505, Los Angeles County, Californ...          693            0
# Census Tract 5510, Los Angeles County, Californ...          916            0
#
#                                                     B02001_007E  B02001_008E
# Census Tract 5433.21, Los Angeles County, Calif...          240          408
# Census Tract 5435.02, Los Angeles County, Calif...         1456          144
# Census Tract 5501, Los Angeles County, Californ...         2810          228
# Census Tract 5505, Los Angeles County, Californ...         1855          261
# Census Tract 5510, Los Angeles County, Californ...         1793          407

# %% [markdown]
# ## Changing column names

# %%
column_names = ['total','white','black','am_indian_alaskan','asian','nhop','other along','two or more']
df_counties.columns = column_names
df_tracts.columns = column_names
df_counties.head()
# Out:
#                                                       total   white  black  \
# Lake County, California: Summary level: 050, st...    64148   49463   1562
# Mariposa County, California: Summary level: 050...    17540   15579    166
# Yuba County, California: Summary level: 050, st...    75493   56344   2432
# Contra Costa County, California: Summary level:...  1133247  648325  97333
# Lassen County, California: Summary level: 050, ...    31185   25672   2738
#
#                                                     am_indian_alaskan   asian  \
# Lake County, California: Summary level: 050, st...               2426     661
# Mariposa County, California: Summary level: 050...                397     243
# Yuba County, California: Summary level: 050, st...               1079    5104
# Contra Costa County, California: Summary level:...               5529  185065
# Lassen County, California: Summary level: 050, ...                877     437
#
#                                                     nhop  other along  \
# Lake County, California: Summary level: 050, st...    30         8048
# Mariposa County, California: Summary level: 050...    54          396
# Yuba County, California: Summary level: 050, st...   343         4126
# Contra Costa County, California: Summary level:...  5585       112976
# Lassen County, California: Summary level: 050, ...   205          590
#
#                                                     two or more
# Lake County, California: Summary level: 050, st...         1958
# Mariposa County, California: Summary level: 050...          705
# Yuba County, California: Summary level: 050, st...         6065
# Contra Costa County, California: Summary level:...        78434
# Lassen County, California: Summary level: 050, ...          666

# %% [markdown]
# ## Adding a new index and name column

# %%
# look at a specific row
df_counties.iloc[0]
# Out:
# total                64148
# white                49463
# black                 1562
# am_indian_alaskan     2426
# asian                  661
# nhop                    30
# other along           8048
# two or more           1958
# Name: Lake County, California: Summary level: 050, state:06> county:033, dtype: int64

# %%
# when you output a column, it shows the index plus the column
df_counties.total.head()
# Out:
# Lake County, California: Summary level: 050, state:06> county:033              64148
# Mariposa County, California: Summary level: 050, state:06> county:043          17540
# Yuba County, California: Summary level: 050, state:06> county:115              75493
# Contra Costa County, California: Summary level: 050, state:06> county:013    1133247
# Lassen County, California: Summary level: 050, state:06> county:035            31185
# Name: total, dtype: int64

# %%
# to put the index into a list, do the following:
df_counties.index.tolist()
# Out:
# [censusgeo((('state', '06'), ('county', '033')), 'Lake County, California'),
#  censusgeo((('state', '06'), ('county', '043')), 'Mariposa County, California'),
#  censusgeo((('state', '06'), ('county', '115')), 'Yuba County, California'),
#  censusgeo((('state', '06'), ('county', '013')), 'Contra Costa County, California'),
#  censusgeo((('state', '06'), ('county', '035')), 'Lassen County, California'),
#  censusgeo((('state', '06'), ('county', '083')), 'Santa Barbara County, California'),
#  censusgeo((('state', '06'), ('county', '097')), 'Sonoma County, California'),
#  censusgeo((('state', '06'), ('county', '025')), 'Imperial County, California'),
#  censusgeo((('state', '06'), ('county', '051')), 'Mono County, California'),
#  censusgeo((('state', '06'), ('county', '001')), 'Alameda County, California'),
#  censusgeo((('state', '06'), ('county', '067')), 'Sacramento County, California'),
#  censusgeo((('state', '06'), ('county', '055')), 'Napa County, California'),
#  censusgeo((('state', '06'), ('county', '053')), 'Monterey County, California'),
#  censusgeo((('state', '06'), ('county', '091')), 'Sierra County, California'),
#  censusgeo((('state', '06'), ('county', '073')), 'San Diego County, California'),
#  censusgeo((('state', '06'), ('county', '113')), 'Yolo County, California'),
#  censusgeo((('state', '06'), ('county', '023')), 'Humboldt County, California'),
#  censusgeo((('state', '06'), ('county', '003')), 'Alpine County, California'),
#  censusgeo((('state', '06'), ('county', '045')), 'Mendocino County, California'),
#  censusgeo((('state', '06'), ('county', '087')), 'Santa Cruz County, California'),
#  censusgeo((('state', '06'), ('county', '037')), 'Los Angeles County, California'),
#  censusgeo((('state', '06'), ('county', '065')), 'Riverside County, California'),
#  censusgeo((('state', '06'), ('county', '085')), 'Santa Clara County, California'),
#  censusgeo((('state', '06'), ('county', '041')), 'Marin County, California'),
#  censusgeo((('state', '06'), ('county', '093')), 'Siskiyou County, California'),
#  censusgeo((('state', '06'), ('county', '089')), 'Shasta County, California'),
#  censusgeo((('state', '06'), ('county', '015')), 'Del Norte County, California'),
#  censusgeo((('state', '06'), ('county', '079')), 'San Luis Obispo County, California'),
#  censusgeo((('state', '06'), ('county', '021')), 'Glenn County, California'),
#  censusgeo((('state', '06'), ('county', '007')), 'Butte County, California'),
#  censusgeo((('state', '06'), ('county', '063')), 'Plumas County, California'),
#  censusgeo((('state', '06'), ('county', '029')), 'Kern County, California'),
#  censusgeo((('state', '06'), ('county', '059')), 'Orange County, California'),
#  censusgeo((('state', '06'), ('county', '009')), 'Calaveras County, California'),
#  censusgeo((('state', '06'), ('county', '101')), 'Sutter County, California'),
#  censusgeo((('state', '06'), ('county', '081')), 'San Mateo County, California'),
#  censusgeo((('state', '06'), ('county', '109')), 'Tuolumne County, California'),
#  censusgeo((('state', '06'), ('county', '077')), 'San Joaquin County, California'),
#  censusgeo((('state', '06'), ('county', '005')), 'Amador County, California'),
#  censusgeo((('state', '06'), ('county', '047')), 'Merced County, California'),
#  censusgeo((('state', '06'), ('county', '049')), 'Modoc County, California'),
#  censusgeo((('state', '06'), ('county', '027')), 'Inyo County, California'),
#  censusgeo((('state', '06'), ('county', '099')), 'Stanislaus County, California'),
#  censusgeo((('state', '06'), ('county', '103')), 'Tehama County, California'),
#  censusgeo((('state', '06'), ('county', '069')), 'San Benito County, California'),
#  censusgeo((('state', '06'), ('county', '017')), 'El Dorado County, California'),
#  censusgeo((('state', '06'), ('county', '075')), 'San Francisco County, California'),
#  censusgeo((('state', '06'), ('county', '107')), 'Tulare County, California'),
#  censusgeo((('state', '06'), ('county', '057')), 'Nevada County, California'),
#  censusgeo((('state', '06'), ('county', '039')), 'Madera County, California'),
#  censusgeo((('state', '06'), ('county', '105')), 'Trinity County, California'),
#  censusgeo((('state', '06'), ('county', '071')), 'San Bernardino County, California'),
#  censusgeo((('state', '06'), ('county', '061')), 'Placer County, California'),
#  censusgeo((('state', '06'), ('county', '095')), 'Solano County, California'),
#  censusgeo((('state', '06'), ('county', '011')), 'Colusa County, California'),
#  censusgeo((('state', '06'), ('county', '031')), 'Kings County, California'),
#  censusgeo((('state', '06'), ('county', '019')), 'Fresno County, California'),
#  censusgeo((('state', '06'), ('county', '111')), 'Ventura County, California')]

# %%
# let's look at this index in more detail... what is it comprised of?
# loop through it and print out the different elements

for index in df_counties.index.tolist():
    print(index)
    print(index.geo)
    print(index.name)
# Out:
# Lake County, California: Summary level: 050, state:06> county:033
# (('state', '06'), ('county', '033'))
# Lake County, California
# Mariposa County, California: Summary level: 050, state:06> county:043
# (('state', '06'), ('county', '043'))
# Mariposa County, California
# Yuba County, California: Summary level: 050, state:06> county:115
# (('state', '06'), ('county', '115'))
# Yuba County, California
# Contra Costa County, California: Summary level: 050, state:06> county:013
# (('state', '06'), ('county', '013'))
# Contra Costa County, California
# Lassen County, California: Summary level: 050, state:06> county:035
# (('state', '06'), ('county', '035'))
# Lassen County, California
# Santa Barbara County, California: Summary level: 050, state:06> county:083
# (('state', '06'), ('county', '083'))
# Santa Barbara County, California
# Sonoma County, California: Summary level: 050, state:06> county:097
# (('state', '06'), ('county', '097'))
# Sonoma County, California
# Imperial County, California: Summary level: 050, state:06> county:025
# (('state', '06'), ('county', '025'))
# Imperial County, California
# Mono County, California: Summary level: 050, state:06> county:051
# (('state', '06'), ('county', '051'))
# Mono County, California
# Alameda County, California: Summary level: 050, state:06> county:001
# (('state', '06'), ('county', '001'))
# Alameda County, California
# Sacramento County, California: Summary level: 050, state:06> county:067
# (('state', '06'), ('county', '067'))
# Sacramento County, California
# Napa County, California: Summary level: 050, state:06> county:055
# (('state', '06'), ('county', '055'))
# Napa County, California
# Monterey County, California: Summary level: 050, state:06> county:053
# (('state', '06'), ('county', '053'))
# Monterey County, California
# Sierra County, California: Summary level: 050, state:06> county:091
# (('state', '06'), ('county', '091'))
# Sierra County, California
# San Diego County, California: Summary level: 050, state:06> county:073
# (('state', '06'), ('county', '073'))
# San Diego County, California
# Yolo County, California: Summary level: 050, state:06> county:113
# (('state', '06'), ('county', '113'))
# Yolo County, California
# Humboldt County, California: Summary level: 050, state:06> county:023
# (('state', '06'), ('county', '023'))
# Humboldt County, California
# Alpine County, California: Summary level: 050, state:06> county:003
# (('state', '06'), ('county', '003'))
# Alpine County, California
# Mendocino County, California: Summary level: 050, state:06> county:045
# (('state', '06'), ('county', '045'))
# Mendocino County, California
# Santa Cruz County, California: Summary level: 050, state:06> county:087
# (('state', '06'), ('county', '087'))
# Santa Cruz County, California
# Los Angeles County, California: Summary level: 050, state:06> county:037
# (('state', '06'), ('county', '037'))
# Los Angeles County, California
# Riverside County, California: Summary level: 050, state:06> county:065
# (('state', '06'), ('county', '065'))
# Riverside County, California
# Santa Clara County, California: Summary level: 050, state:06> county:085
# (('state', '06'), ('county', '085'))
# Santa Clara County, California
# Marin County, California: Summary level: 050, state:06> county:041
# (('state', '06'), ('county', '041'))
# Marin County, California
# Siskiyou County, California: Summary level: 050, state:06> county:093
# (('state', '06'), ('county', '093'))
# Siskiyou County, California
# Shasta County, California: Summary level: 050, state:06> county:089
# (('state', '06'), ('county', '089'))
# Shasta County, California
# Del Norte County, California: Summary level: 050, state:06> county:015
# (('state', '06'), ('county', '015'))
# Del Norte County, California
# San Luis Obispo County, California: Summary level: 050, state:06> county:079
# (('state', '06'), ('county', '079'))
# San Luis Obispo County, California
# Glenn County, California: Summary level: 050, state:06> county:021
# (('state', '06'), ('county', '021'))
# Glenn County, California
# Butte County, California: Summary level: 050, state:06> county:007
# (('state', '06'), ('county', '007'))
# Butte County, California
# Plumas County, California: Summary level: 050, state:06> county:063
# (('state', '06'), ('county', '063'))
# Plumas County, California
# Kern County, California: Summary level: 050, state:06> county:029
# (('state', '06'), ('county', '029'))
# Kern County, California
# Orange County, California: Summary level: 050, state:06> county:059
# (('state', '06'), ('county', '059'))
# Orange County, California
# Calaveras County, California: Summary level: 050, state:06> county:009
# (('state', '06'), ('county', '009'))
# Calaveras County, California
# Sutter County, California: Summary level: 050, state:06> county:101
# (('state', '06'), ('county', '101'))
# Sutter County, California
# San Mateo County, California: Summary level: 050, state:06> county:081
# (('state', '06'), ('county', '081'))
# San Mateo County, California
# Tuolumne County, California: Summary level: 050, state:06> county:109
# (('state', '06'), ('county', '109'))
# Tuolumne County, California
# San Joaquin County, California: Summary level: 050, state:06> county:077
# (('state', '06'), ('county', '077'))
# San Joaquin County, California
# Amador County, California: Summary level: 050, state:06> county:005
# (('state', '06'), ('county', '005'))
# Amador County, California
# Merced County, California: Summary level: 050, state:06> county:047
# (('state', '06'), ('county', '047'))
# Merced County, California
# Modoc County, California: Summary level: 050, state:06> county:049
# (('state', '06'), ('county', '049'))
# Modoc County, California
# Inyo County, California: Summary level: 050, state:06> county:027
# (('state', '06'), ('county', '027'))
# Inyo County, California
# Stanislaus County, California: Summary level: 050, state:06> county:099
# (('state', '06'), ('county', '099'))
# Stanislaus County, California
# Tehama County, California: Summary level: 050, state:06> county:103
# (('state', '06'), ('county', '103'))
# Tehama County, California
# San Benito County, California: Summary level: 050, state:06> county:069
# (('state', '06'), ('county', '069'))
# San Benito County, California
# El Dorado County, California: Summary level: 050, state:06> county:017
# (('state', '06'), ('county', '017'))
# El Dorado County, California
# San Francisco County, California: Summary level: 050, state:06> county:075
# (('state', '06'), ('county', '075'))
# San Francisco County, California
# Tulare County, California: Summary level: 050, state:06> county:107
# (('state', '06'), ('county', '107'))
# Tulare County, California
# Nevada County, California: Summary level: 050, state:06> county:057
# (('state', '06'), ('county', '057'))
# Nevada County, California
# Madera County, California: Summary level: 050, state:06> county:039
# (('state', '06'), ('county', '039'))
# Madera County, California
# Trinity County, California: Summary level: 050, state:06> county:105
# (('state', '06'), ('county', '105'))
# Trinity County, California
# San Bernardino County, California: Summary level: 050, state:06> county:071
# (('state', '06'), ('county', '071'))
# San Bernardino County, California
# Placer County, California: Summary level: 050, state:06> county:061
# (('state', '06'), ('county', '061'))
# Placer County, California
# Solano County, California: Summary level: 050, state:06> county:095
# (('state', '06'), ('county', '095'))
# Solano County, California
# Colusa County, California: Summary level: 050, state:06> county:011
# (('state', '06'), ('county', '011'))
# Colusa County, California
# Kings County, California: Summary level: 050, state:06> county:031
# (('state', '06'), ('county', '031'))
# Kings County, California
# Fresno County, California: Summary level: 050, state:06> county:019
# (('state', '06'), ('county', '019'))
# Fresno County, California
# Ventura County, California: Summary level: 050, state:06> county:111
# (('state', '06'), ('county', '111'))
# Ventura County, California

# %%
# create two new columns, one for fips, and one for county name
state_county_fips = []
county_names = []

for index in df_counties.index.tolist():
    new_index = index.geo[0][1] + index.geo[1][1]
    state_county_fips.append(new_index)
    county_name = index.name.split(',')[0]
    county_names.append(county_name)

# %%
# do the same for the census tracts
tract_fips = []
tract_names = []

for index in df_tracts.index.tolist():
    new_index = index.geo[0][1] + index.geo[1][1] + index.geo[2][1]
    tract_fips.append(new_index)
    tract_name = index.name.split(',')[0]
    tract_names.append(tract_name)

# %%
state_county_fips
tract_fips

# %%
# create a new index with our fips code
df_counties.index = state_county_fips

# add a county name column
df_counties['county_name'] = county_names

# %%
df_counties.head()

# %%
# create a new index with our fips code
df_tracts.index = tract_fips

# add a tract name column
df_tracts['tract_name'] = tract_names

# %%
df_tracts.head()

# %% [markdown]
# ## Mapping our census data

# %%
# import the us county geojson
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

# %%
counties["features"][0]

# %%
# census tracts
with urlopen('https://opendata.arcgis.com/datasets/152f90d3a34a43ef998448281505d45e_0.geojson') as response:
    tracts = json.load(response)

# %%
# let's look like one of these features looks like
tracts["features"][0]

# %%
import plotly.express as px

fig = px.choropleth(df_tracts, 
                    geojson=tracts, 
                    locations=df_tracts.index, 
                    featureidkey="properties.FIPS", # this is the join column
                    color='black',
                    color_continuous_scale="Viridis",                    
                    projection="mercator"
                          )

# zoom to the geographies with data
fig.update_geos(fitbounds="locations", visible=False)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()

# %%
import plotly.express as px

fig = px.choropleth(df_counties, 
                    geojson=counties, 
                    locations=df_counties.index, 
                    color='black',
                    color_continuous_scale="Viridis",
                    scope="usa"
                          )

# show just the geographies with data
fig.update_geos(fitbounds="locations", visible=False)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()

# %%
# how about normalizing the data?
df_counties['percent_white'] = df_counties['white'] / df_counties['total'] * 100
df_counties['percent_black'] = df_counties['black'] / df_counties['total'] * 100
df_tracts['percent_white'] = df_tracts['white'] / df_tracts['total'] * 100
df_tracts['percent_black'] = df_tracts['black'] / df_tracts['total'] * 100

# %%
df_tracts.head()

# %%
import plotly.express as px

fig = px.choropleth(df_tracts, 
                    geojson=tracts, 
                    locations=df_tracts.index, 
                    featureidkey="properties.FIPS", # this is the join column
                    color='percent_black',
                    color_continuous_scale="Viridis",                    
                    projection="mercator"
                   )

# show just the geographies with data
fig.update_geos(fitbounds="locations", visible=False)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()

# %%
import plotly.express as px

fig = px.choropleth(df_counties, 
                    geojson=counties, 
                    locations=df_counties.index, 
                    color='percent_black',
                    color_continuous_scale="Viridis",
                    scope="usa"
                          )

# show just the geographies with data
fig.update_geos(fitbounds="locations", visible=False)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()

# %%
# use mapbox
fig = px.choropleth_mapbox(df_counties, 
                            geojson=counties, 
                            locations=df_counties.index, 
                            color='percent_white',
                            color_continuous_scale="Viridis",
                            mapbox_style="carto-positron",
                            zoom=3, center = {"lat": 37.0902, "lon": -120},
                            opacity=0.5,
                          )

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
