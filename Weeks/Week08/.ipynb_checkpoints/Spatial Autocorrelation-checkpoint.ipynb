# %%
import esda
from esda.moran import Moran, Moran_Local

import splot
from splot.esda import moran_scatterplot, plot_moran, lisa_cluster

import libpysal as lps

# %%
# Graphics
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn
# from pysal.viz.splot.esda import plot_moran
import contextily

# %%
# Analysis
import geopandas
import pandas
# from pysal.explore import esda
# from pysal.lib import weights
from numpy.random import seed

# %%
# to read and wrangle data
import pandas as pd

# to import data from LA Data portal
from sodapy import Socrata

# to create spatial data
import geopandas as gpd

# for basemaps
import contextily as ctx

# for interactive leaflet mapping
import folium

# to handle thousands of markers
from folium.plugins import MarkerCluster

# %% [markdown]
# ## LA Times Census Tracts
#
# * [Download the data](http://boundaries.latimes.com/sets/)

# %%
# get neighborhood boundaries from the LA Times
# neighborhoods = gpd.read_file('http://s3-us-west-2.amazonaws.com/boundaries.latimes.com/archive/1.0/boundary-set/la-county-neighborhoods-v5.geojson')

# %%
# get census tract boundaries from the LA Times
tracts = gpd.read_file('http://boundaries.latimes.com/1.0/boundary-set/census-tracts-2012/?format=geojson')

# %%
# trim the data to the bare minimum columns
tracts = tracts[['name','geometry']]
tracts.head()
# Out:
#           name                                           geometry
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...

# %%
# get the layers into a web mercator projection
# reproject to web mercator
tracts = tracts.to_crs(epsg=3857)

# %%
# plot it!
ax=tracts.plot(figsize=(12,12),
                      color='gray', 
                      edgecolor='white',
                      alpha=0.5)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# ## Get Arrest Data from LA Open Data Portal
# Next, we acquire the data using the socrata API. Use the socrata documentation to grab the code syntax for our arrests data.
# - https://dev.socrata.com/foundry/data.lacity.org/amvf-fr72

# %%
import pandas as pd
import plotly.express as px
from sodapy import Socrata

# %%
# connect to the data portal
client = Socrata("data.lacity.org", None)

results = client.get("amvf-fr72", 
                     limit=50000,
                     where = "arst_date between '2020-03-01T00:00:00' and '2020-09-30T00:00:00'",
                     order='arst_date desc')

# Convert to pandas DataFrame
arrests = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
arrests.shape
# Out:
# (36216, 25)

# %% [markdown]
# ## Convert data to a geodataframe
#
# Geopandas allows us to convert different types of data into a spatial format.
# - https://geopandas.org/gallery/create_geopandas_from_pandas.html

# %%
# convert pandas dataframe to geodataframe
arrests = gpd.GeoDataFrame(arrests, 
                         crs='EPSG:4326',
                         geometry=gpd.points_from_xy(arrests.lon, arrests.lat))

# %%
# get the layers into a web mercator projection
# reproject to web mercator
arrests = arrests.to_crs(epsg=3857)

# %%
arrests.lon = arrests.lon.astype('float')

# %%
arrests.lat = arrests.lat.astype('float')

# %%
# map it!
ax = arrests.plot(figsize=(12,12),color='red')

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
arrests[arrests.lon==0]
# Out:
#         rpt_id report_type                arst_date  time area  area_desc  \
# 18173  5951250     BOOKING  2020-06-09T00:00:00.000  0025   06  Hollywood
# 26039  5921308     BOOKING  2020-04-26T00:00:00.000  1500   19    Mission
#
#          rd age sex_cd descent_cd  ...                         location  lat  \
# 18173  0665  39      M          O  ...                         FOUNTAIN  0.0
# 26039  1942  25      M          H  ...  REGAN                        FY  0.0
#
#        lon                                location_1                 bkg_date  \
# 18173  0.0  {'type': 'Point', 'coordinates': [0, 0]}  2020-06-09T00:00:00.000
# 26039  0.0  {'type': 'Point', 'coordinates': [0, 0]}  2020-04-26T00:00:00.000
#
#       bkg_time       bgk_location  bkg_loc_cd  \
# 18173     0224          HOLLYWOOD        4206
# 26039     1631  VALLEY - JAIL DIV        4279
#
#                                  crsst                 geometry
# 18173                         MACCADEN  POINT (0.00000 0.00000)
# 26039  LAUREL CANYON                BL  POINT (0.00000 0.00000)
#
# [2 rows x 26 columns]

# %%
# drop the unmapped rows
arrests.drop(arrests[arrests.lon==0].index,inplace=True)

# %%
# map it!
ax = arrests.plot(figsize=(12,12),color='red',markersize=1,alpha=0.5)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# ## Create a two layer map
#
# - https://geopandas.org/mapping.html

# %%
# first define which layers will be your "base"
base = tracts.plot(figsize=(12,10),
                      color='gray', 
                      edgecolor='white',
                      alpha=0.5)

# define the layer that will go on top, and add the base layer to the `ax` argument
ax = arrests.plot(ax=base, color='red',markersize=1,alpha=0.5)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# ## Zoom to the points, not the neighborhoods
#
# By default, the map has zoomed out to fit both layers. Sometimes, we may want to zoom to the extent of a smaller layer, in this case, the crime data.

# %%
# get the bounding box coordinates for the crime data
arrests.geometry.total_bounds
# Out:
# array([-13209059.45803905,   3989526.81108362, -13153388.58069333,
#          4072889.46565252])

# %%
# shortcut to put them into their own variables
minx, miny, maxx, maxy = arrests.geometry.total_bounds
print(minx)
print(maxx)
print(miny)
print(maxy)
# Out:
# -13209059.458039049
# -13153388.580693332
# 3989526.8110836204
# 4072889.465652517

# %%
# use the bounding box coordinates to set the x and y limits
base = tracts.plot(figsize=(12,12),
                          color='gray', 
                          edgecolor='white',
                          alpha=0.5)

ax = arrests.plot(ax=base, 
                color='red',markersize=1,alpha=0.5)

ax.set_xlim(minx - 1000, maxx + 1000) # added/substracted value is to give some margin around total bounds
ax.set_ylim(miny - 1000, maxy + 1000)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

ax

# %% [markdown]
# ## The spatial join
#
# * https://geopandas.org/mergingdata.html?highlight=spatial%20join
#
# In a Spatial Join, two geometry objects are merged based on their spatial relationship to one another.
#
# The how argument specifies the type of join that will occur and which geometry is retained in the resultant geodataframe. It accepts the following options:
#
# `left`: use the index from the first (or left_df) geodataframe that you provide to sjoin; retain only the left_df geometry column
#
# `right`: use index from second (or right_df); retain only the right_df geometry column
#
# `inner`: use intersection of index values from both geodataframes; retain only the left_df geometry column

# %%
# Do the spatial join
join = gpd.sjoin(tracts,
                 arrests,
                 how='right')

# %% [markdown]
# Next, we create a dataframe that counts crime by neighborhood:

# %%
arrests_by_tracts = join.name.value_counts().rename_axis('name').reset_index(name='arrests_count')

# %%
arrests_by_tracts.head()
# Out:
#           name  arrests_count
# 0  06037980028            705
# 1  06037206300            477
# 2  06037237600            440
# 3  06037273402            405
# 4  06037208801            357

# %%
# make a bar chart
arrests_by_tracts[:50].plot.bar(figsize=(20,8),x='name',y='arrests_count')

# %% [markdown]
# ## Join the value counts back to the neighborhoods
#
# The bar chart is nice, but what we also want is a choropleth map to accompany it. To do so, we merge the counts back to the neighborhoods.

# %%
# join the summary table back to the neighborhood geodatabase
tracts=tracts.merge(arrests_by_tracts,on='name')

# %%
# our neighborhood table now has a count column
tracts.head()
# Out:
#           name                                           geometry  \
# 0  06037101110  MULTIPOLYGON (((-13169350.794 4063591.834, -13...
# 1  06037101122  MULTIPOLYGON (((-13169466.900 4065590.632, -13...
# 2  06037101210  MULTIPOLYGON (((-13169034.646 4063225.625, -13...
# 3  06037101220  MULTIPOLYGON (((-13167528.828 4062280.326, -13...
# 4  06037101300  MULTIPOLYGON (((-13166031.469 4060067.620, -13...
#
#    arrests_count
# 0             14
# 1              7
# 2             28
# 3             20
# 4              7

# %% [markdown]
# ## Map neighborhoods by crime count

# %%
# reproject to web mercator
tracts = tracts.to_crs(epsg=3857)

# %%
# reproject to web mercator
arrests = arrests.to_crs(epsg=3857)

# %%
# shortcut to put them into their own variables
minx, miny, maxx, maxy = arrests.geometry.total_bounds
print(minx)
print(maxx)
print(miny)
print(maxy)
# Out:
# -13209059.458039049
# -13153388.580693332
# 3989526.8110836204
# 4072889.465652517

# %%
ax = tracts.plot(figsize=(15,15),
                        column='arrests_count',
                        legend=True,
                        alpha=0.8,
                        cmap='RdYlGn_r',scheme='quantiles')

ax.axis('off')
ax.set_title('September 2020 Arrests by the LAPD',fontsize=22)
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# ## Spatial Autocorrelation

# %%
tracts.head()
# Out:
#           name                                           geometry  \
# 0  06037101110  MULTIPOLYGON (((-13169350.794 4063591.834, -13...
# 1  06037101122  MULTIPOLYGON (((-13169466.900 4065590.632, -13...
# 2  06037101210  MULTIPOLYGON (((-13169034.646 4063225.625, -13...
# 3  06037101220  MULTIPOLYGON (((-13167528.828 4062280.326, -13...
# 4  06037101300  MULTIPOLYGON (((-13166031.469 4060067.620, -13...
#
#    arrests_count
# 0             14
# 1              7
# 2             28
# 3             20
# 4              7

# %%
# apply weight
wq =  lps.weights.Queen.from_dataframe(tracts,idVariable='name')
wq.transform = 'r'
# Out:
# ('WARNING: ', '06037535606', ' is an island (no neighbors)')
# ('WARNING: ', '06037571400', ' is an island (no neighbors)')
# ('WARNING: ', '06037601600', ' is an island (no neighbors)')
# /opt/conda/lib/python3.8/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 5 disconnected components.
#  There are 3 islands with ids: 06037535606, 06037571400, 06037601600.
#   warnings.warn(message)

# %%
no_neighbors=tracts.loc[tracts.name.isin(['06037535606','06037571400','06037601600'])]

# %%
tracts.plot()

# %%
no_neighbors.plot(color='red')

# %%
# first define which layers will be your "base"
base = tracts.plot(figsize=(12,10),
                      color='gray', 
                      edgecolor='white',
                      alpha=0.5)

# define the layer that will go on top, and add the base layer to the `ax` argument
ax = no_neighbors.plot(ax=base, color='red',edgecolor='white',)

# %%
# drop the problematic geographies
tracts.drop(tracts.loc[tracts.name.isin(['06037535606','06037571400','06037601600'])].index,inplace=True)

# %%
# apply weight again
wq =  lps.weights.Queen.from_dataframe(tracts,idVariable='name')
wq.transform = 'r'
# Out:
# /opt/conda/lib/python3.8/site-packages/libpysal/weights/weights.py:172: UserWarning: The weights matrix is not fully connected:
#  There are 2 disconnected components.
#   warnings.warn(message)

# %%
# create a new column for lag
tracts['arrests_count_lag'] = lps.weights.lag_spatial(wq, tracts['arrests_count'])

# %%
tracts.sample(20)
# Out:
#              name                                           geometry  \
# 601   06037212305  MULTIPOLYGON (((-13169072.606 4036167.809, -13...
# 939   06037292000  MULTIPOLYGON (((-13170110.327 4007009.360, -13...
# 150   06037121010  MULTIPOLYGON (((-13181169.473 4057826.267, -13...
# 962   06037294900  MULTIPOLYGON (((-13166991.043 3997799.067, -13...
# 533   06037206200  MULTIPOLYGON (((-13163259.280 4034988.974, -13...
# 645   06037218110  MULTIPOLYGON (((-13172855.688 4035196.410, -13...
# 839   06037264302  MULTIPOLYGON (((-13190449.622 4035289.650, -13...
# 616   06037213310  MULTIPOLYGON (((-13169092.533 4035391.892, -13...
# 100   06037113421  MULTIPOLYGON (((-13201769.145 4059617.240, -13...
# 446   06037192410  MULTIPOLYGON (((-13171620.153 4039408.418, -13...
# 906   06037273700  MULTIPOLYGON (((-13186818.269 4028422.033, -13...
# 238   06037128303  MULTIPOLYGON (((-13186622.235 4053104.020, -13...
# 134   06037119342  MULTIPOLYGON (((-13185820.735 4061104.974, -13...
# 329   06037141102  MULTIPOLYGON (((-13184200.703 4048311.103, -13...
# 213   06037127102  MULTIPOLYGON (((-13185655.648 4056094.665, -13...
# 761   06037236204  MULTIPOLYGON (((-13174825.598 4030446.483, -13...
# 128   06037119201  MULTIPOLYGON (((-13185589.413 4062026.069, -13...
# 776   06037238000  MULTIPOLYGON (((-13171068.454 4021563.378, -13...
# 4     06037101300  MULTIPOLYGON (((-13166031.469 4060067.620, -13...
# 1046  06037980026  MULTIPOLYGON (((-13174854.541 4066507.512, -13...
#
#       arrests_count  arrests_count_lag
# 601              11          22.333333
# 939              53           9.750000
# 150              45          32.428571
# 962              23          43.500000
# 533             211         279.666667
# 645              42          37.333333
# 839              11          14.666667
# 616              28          29.714286
# 100              23          39.600000
# 446               7          40.000000
# 906              21          24.500000
# 238              60          88.833333
# 134               6          29.600000
# 329              11          12.666667
# 213             123          49.000000
# 761              51          56.666667
# 128              21          22.600000
# 776              77          67.000000
# 4                 7          10.750000
# 1046              3          17.500000

# %%
ax = tracts.plot(figsize=(15,15),
                        column='arrests_count_lag',
                        legend=True,
                        alpha=0.8,
                        cmap='RdYlGn_r',scheme='quantiles')

ax.axis('off')
ax.set_title('September 2020 Arrests by the LAPD',fontsize=22)
# ax = arrests.plot(ax=ax, color='blue',markersize =1,alpha=0.2, legend=True)
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
# what is the median number of arrests per neighborhood?
median = tracts.arrests_count.median()
median
# Out:
# 23.0

# %%
# visualize as a binary
tracts['above_arrest_median'] = (tracts['arrests_count'] > median).astype(int)

# %%
tracts.head()
# Out:
#           name                                           geometry  \
# 0  06037101110  MULTIPOLYGON (((-13169350.794 4063591.834, -13...
# 1  06037101122  MULTIPOLYGON (((-13169466.900 4065590.632, -13...
# 2  06037101210  MULTIPOLYGON (((-13169034.646 4063225.625, -13...
# 3  06037101220  MULTIPOLYGON (((-13167528.828 4062280.326, -13...
# 4  06037101300  MULTIPOLYGON (((-13166031.469 4060067.620, -13...
#
#    arrests_count  arrests_count_lag  above_arrest_median
# 0             14              18.00                    0
# 1              7              11.00                    0
# 2             28              17.50                    1
# 3             20              13.75                    0
# 4              7              10.75                    0

# %%
ax = tracts.plot(figsize=(15,15),
                        column='above_arrest_median',
                        legend=True,
                        alpha=0.8,
                        cmap='RdYlGn_r',
                        categorical=True,)

ax.axis('off')
ax.set_title('September 2020 Arrests Above the Median',fontsize=22)
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
import numpy as np
wq.transform = 'r'
np.random.seed(12345)
mi = esda.moran.Moran(tracts.arrests_count, wq)
mi.I
# Out:
# 0.30639914463026974

# %%
import seaborn as sbn
sbn.kdeplot(mi.sim, shade=True)
plt.vlines(mi.I, 0, 1, color='r')
plt.vlines(mi.EI, 0,1)
plt.xlabel("Moran's I")
# Out:
# Text(0.5, 0, "Moran's I")

# %%
mi.p_sim
# Out:
# 0.001

# %%
y = tracts.arrests_count
moran = Moran(y, wq)
moran.I
# Out:
# 0.30639914463026974

# %%
fig, ax = moran_scatterplot(moran, aspect_equal=True)
plt.show()

# %%
li = esda.moran.Moran_Local(y, wq)

# %%
# calculate Moran Local 
m_local = Moran_Local(y, wq)
m_local

# %%
# Plot
fig, ax = moran_scatterplot(m_local, p=0.05)
# ax.set_xlabel(‘Price’)
# ax.set_ylabel(‘Spatial Lag of Price’)
plt.text(1.95, 0.5, "HH", fontsize=25)
plt.text(1.95, -1.5, "HL", fontsize=25)
plt.text(-2, 1, "LH", fontsize=25)
plt.text(-1, -1, "LL", fontsize=25)
plt.show()

# %%
plot_moran(moran);

# %%
fig, ax = plt.subplots(figsize=(14,12))
lisa_cluster(m_local, tracts, p=0.05, figsize = (16,12),ax=ax)
plt.show()
