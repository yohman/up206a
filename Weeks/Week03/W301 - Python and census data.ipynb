# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Pandas-and-census-data" data-toc-modified-id="Pandas-and-census-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Pandas and census data</a></span><ul class="toc-item"><li><span><a href="#Where-to-get-census-data?" data-toc-modified-id="Where-to-get-census-data?-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Where to get census data?</a></span><ul class="toc-item"><li><span><a href="#Social-Explorer" data-toc-modified-id="Social-Explorer-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Social Explorer</a></span></li></ul></li><li><span><a href="#Importing-data" data-toc-modified-id="Importing-data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Importing data</a></span></li><li><span><a href="#Preliminary-inspection" data-toc-modified-id="Preliminary-inspection-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Preliminary inspection</a></span></li><li><span><a href="#Data-types" data-toc-modified-id="Data-types-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Data types</a></span></li><li><span><a href="#Assigning-data-types-on-import" data-toc-modified-id="Assigning-data-types-on-import-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Assigning data types on import</a></span><ul class="toc-item"><li><span><a href="#The-leading-zero-dilemma..." data-toc-modified-id="The-leading-zero-dilemma...-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>The leading zero dilemma...</a></span></li><li><span><a href="#The-FIPS-code" data-toc-modified-id="The-FIPS-code-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>The FIPS code</a></span></li></ul></li><li><span><a href="#Getting-a-list-of-column-names" data-toc-modified-id="Getting-a-list-of-column-names-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Getting a list of column names</a></span></li></ul></li><li><span><a href="#Add-Subsetting-here" data-toc-modified-id="Add-Subsetting-here-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Add Subsetting here</a></span><ul class="toc-item"><li><span><a href="#Simple-stats-and-plots" data-toc-modified-id="Simple-stats-and-plots-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Simple stats and plots</a></span></li><li><span><a href="#Getting-unique-or-distinct-values-in-a-column" data-toc-modified-id="Getting-unique-or-distinct-values-in-a-column-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Getting unique or distinct values in a column</a></span></li><li><span><a href="#Replacing-values,-creating-new-columns" data-toc-modified-id="Replacing-values,-creating-new-columns-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Replacing values, creating new columns</a></span></li><li><span><a href="#Displaying-null/missing-values" data-toc-modified-id="Displaying-null/missing-values-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Displaying null/missing values</a></span></li><li><span><a href="#Sorting" data-toc-modified-id="Sorting-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Sorting</a></span></li><li><span><a href="#Filtering-and-subsetting-data" data-toc-modified-id="Filtering-and-subsetting-data-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Filtering and subsetting data</a></span></li><li><span><a href="#Combining-queries" data-toc-modified-id="Combining-queries-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Combining queries</a></span></li><li><span><a href="#Start-plotting-this-data" data-toc-modified-id="Start-plotting-this-data-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Start plotting this data</a></span></li><li><span><a href="#Case-study:-Race-analysis" data-toc-modified-id="Case-study:-Race-analysis-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Case study: Race analysis</a></span><ul class="toc-item"><li><span><a href="#race-variables" data-toc-modified-id="race-variables-2.9.1"><span class="toc-item-num">2.9.1&nbsp;&nbsp;</span>race variables</a></span></li></ul></li><li><span><a href="#Grouping" data-toc-modified-id="Grouping-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Grouping</a></span></li></ul></li><li><span><a href="#Maps!" data-toc-modified-id="Maps!-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Maps!</a></span><ul class="toc-item"><li><span><a href="#Geopandas-to-read-geojson" data-toc-modified-id="Geopandas-to-read-geojson-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Geopandas to read geojson</a></span></li><li><span><a href="#Merging/joining-data" data-toc-modified-id="Merging/joining-data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Merging/joining data</a></span></li><li><span><a href="#Folium" data-toc-modified-id="Folium-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Folium</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Pandas and census data
# Overview of this week's notebook:
#
# - how and where to find and download census data
# - use pandas to read a csv file
# - learn how to delete rows

# %% [markdown]
# ## Where to get census data?
#
# Well, you have many options, including, getting it directly from the source, the census bureau website itself. However, as part of the academic community, we are offered a great resource: Social Explorer. With a campus-wide license to have full access to their website, you can download any census variable, that pretty much existed... ever. And, with its easy-to-use user interface, this is a wonderful one-stop shop for your census needs.
#
# ### Social Explorer

# %% [markdown]
# ## Importing data
#
# As always, in order to work with data in python, we need a library that will let us handle "data exploration." We looked at geopandas last week, but let's go to its origin, the one and only, `pandas` library.
#
# * https://pandas.pydata.org/

# %%
import pandas as pd

# %% [markdown]
# Next, we make the call to load and read the data that was downloaded from social explorer. Again, take note at the relative path reference to find the file in your file directory.

# %%
# load a data file
# note the relative filepath! where is this file located?
df = pd.read_csv('../../data/se_ca.csv')

# %% [markdown]
# ## Preliminary inspection
# A quick look at the size of the data.

# %%
df.shape
# Out:
# (3754, 140)

# %%
df.head()
# Out:
#      Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  6037101110  14000US06037101110  Census Tract 1011.10
# 1  6037101122  14000US06037101122  Census Tract 1011.22
# 2  6037101210  14000US06037101210  Census Tract 1012.10
# 3  6037101220  14000US06037101220  Census Tract 1012.20
# 4  6037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 0            0      ACSSF          3870     NaN         NaN           NaN
# 1            0      ACSSF          3871     NaN         NaN           NaN
# 2            0      ACSSF          3872     NaN         NaN           NaN
# 3            0      ACSSF          3873     NaN         NaN           NaN
# 4            0      ACSSF          3874     NaN         NaN           NaN
#
#    Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_PLACESE  \
# 0          NaN          6          37         NaN        NaN          NaN
# 1          NaN          6          37         NaN        NaN          NaN
# 2          NaN          6          37         NaN        NaN          NaN
# 3          NaN          6          37         NaN        NaN          NaN
# 4          NaN          6          37         NaN        NaN          NaN
#
#    Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  Geo_AIHHTLI  \
# 0     101110         NaN         NaN         NaN           NaN          NaN
# 1     101122         NaN         NaN         NaN           NaN          NaN
# 2     101210         NaN         NaN         NaN           NaN          NaN
# 3     101220         NaN         NaN         NaN           NaN          NaN
# 4     101300         NaN         NaN         NaN           NaN          NaN
#
#    Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  Geo_CSA  Geo_METDIV  Geo_MACC  \
# 0         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 1         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 2         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 3         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 4         NaN       NaN       NaN       NaN      NaN         NaN       NaN
#
#    Geo_MEMI  Geo_NECTA  Geo_CNECTA  Geo_NECTADIV  Geo_UA  Geo_UACP  \
# 0       NaN        NaN         NaN           NaN     NaN       NaN
# 1       NaN        NaN         NaN           NaN     NaN       NaN
# 2       NaN        NaN         NaN           NaN     NaN       NaN
# 3       NaN        NaN         NaN           NaN     NaN       NaN
# 4       NaN        NaN         NaN           NaN     NaN       NaN
#
#    Geo_CDCURR  Geo_SLDU  Geo_SLDL  Geo_VTD  Geo_ZCTA3  Geo_ZCTA5  Geo_SUBMCD  \
# 0         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 1         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 2         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 3         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 4         NaN       NaN       NaN      NaN        NaN        NaN         NaN
#
#    Geo_SDELM  Geo_SDSEC  Geo_SDUNI  Geo_UR  Geo_PCI  Geo_TAZ  Geo_UGA  \
# 0        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 1        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 2        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 3        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 4        NaN        NaN        NaN     NaN      NaN      NaN      NaN
#
#    Geo_BTTR  Geo_BTBG  Geo_PUMA5  Geo_PUMA1  SE_A00001_001  SE_A03001_001  \
# 0       NaN       NaN        NaN        NaN           4314           4314
# 1       NaN       NaN        NaN        NaN           3239           3239
# 2       NaN       NaN        NaN        NaN           6052           6052
# 3       NaN       NaN        NaN        NaN           3497           3497
# 4       NaN       NaN        NaN        NaN           4297           4297
#
#    SE_A03001_002  SE_A03001_003  SE_A03001_004  SE_A03001_005  SE_A03001_006  \
# 0           3314             47              4            329              4
# 1           2837             61             13            206              0
# 2           4771            172              0            260              0
# 3           2494             71              0            302              0
# 4           3705            161              0            289              0
#
#    SE_A03001_007  SE_A03001_008  PCT_SE_A03001_002  PCT_SE_A03001_003  \
# 0            499            117              76.82               1.09
# 1             61             61              87.59               1.88
# 2            736            113              78.83               2.84
# 3            487            143              71.32               2.03
# 4             48             94              86.22               3.75
#
#    PCT_SE_A03001_004  PCT_SE_A03001_005  PCT_SE_A03001_006  PCT_SE_A03001_007  \
# 0               0.09               7.63               0.09              11.57
# 1               0.40               6.36               0.00               1.88
# 2               0.00               4.30               0.00              12.16
# 3               0.00               8.64               0.00              13.93
# 4               0.00               6.73               0.00               1.12
#
#    PCT_SE_A03001_008  SE_A12001_001  SE_A12001_002  SE_A12001_003  \
# 0               2.71           3085            524            765
# 1               1.88           2597            168            749
# 2               1.87           4107            762           1185
# 3               4.09           2484            515            700
# 4               2.19           3446            362            949
#
#    SE_A12001_004  SE_A12001_005  SE_A12001_006  SE_A12001_007  SE_A12001_008  \
# 0           1101            411            180             50             54
# 1            888            463            248             13             68
# 2           1340            548            174             36             62
# 3            769            347            129              0             24
# 4           1145            604            278             82             26
#
#    PCT_SE_A12001_002  PCT_SE_A12001_003  PCT_SE_A12001_004  PCT_SE_A12001_005  \
# 0              16.99              24.80              35.69              13.32
# 1               6.47              28.84              34.19              17.83
# 2              18.55              28.85              32.63              13.34
# 3              20.73              28.18              30.96              13.97
# 4              10.50              27.54              33.23              17.53
#
#    PCT_SE_A12001_006  PCT_SE_A12001_007  PCT_SE_A12001_008  SE_A12002_001  \
# 0               5.83               1.62               1.75           3085
# 1               9.55               0.50               2.62           2597
# 2               4.24               0.88               1.51           4107
# 3               5.19               0.00               0.97           2484
# 4               8.07               2.38               0.75           3446
#
#    SE_A12002_002  SE_A12002_003  SE_A12002_004  SE_A12002_005  SE_A12002_006  \
# 0            524           2561           1796            695            284
# 1            168           2429           1680            792            329
# 2            762           3345           2160            820            272
# 3            515           1969           1269            500            153
# 4            362           3084           2135            990            386
#
#    SE_A12002_007  SE_A12002_008  PCT_SE_A12002_002  PCT_SE_A12002_003  \
# 0            104             54              16.99              83.01
# 1             81             68               6.47              93.53
# 2             98             62              18.55              81.45
# 3             24             24              20.73              79.27
# 4            108             26              10.50              89.50
#
#    PCT_SE_A12002_004  PCT_SE_A12002_005  PCT_SE_A12002_006  PCT_SE_A12002_007  \
# 0              58.22              22.53               9.21               3.37
# 1              64.69              30.50              12.67               3.12
# 2              52.59              19.97               6.62               2.39
# 3              51.09              20.13               6.16               0.97
# 4              61.96              28.73              11.20               3.13
#
#    PCT_SE_A12002_008  SE_A14006_001  SE_A09005_001  SE_A09005_002  \
# 0               1.75        53077.0           1927           1763
# 1               2.62        88953.0           1907           1776
# 2               1.51        32119.0           2770           2445
# 3               0.97        41728.0           1513           1360
# 4               0.75        86914.0           2041           1765
#
#    SE_A09005_009  SE_A09005_010  SE_A09005_003  SE_A09005_004  SE_A09005_005  \
# 0           1588            175             46              0              0
# 1           1645            131              7              0              0
# 2           2235            210             95              0              0
# 3           1235            125             55              0              0
# 4           1631            134             86              0              0
#
#    SE_A09005_006  SE_A09005_007  SE_A09005_008  PCT_SE_A09005_002  \
# 0              0             20             98              91.49
# 1             11             40             73              93.13
# 2             91             33            106              88.27
# 3              0             23             75              89.89
# 4              0              0            190              86.48
#
#    PCT_SE_A09005_009  PCT_SE_A09005_010  PCT_SE_A09005_003  PCT_SE_A09005_004  \
# 0              82.41               9.08               2.39                0.0
# 1              86.26               6.87               0.37                0.0
# 2              80.69               7.58               3.43                0.0
# 3              81.63               8.26               3.64                0.0
# 4              79.91               6.57               4.21                0.0
#
#    PCT_SE_A09005_005  PCT_SE_A09005_006  PCT_SE_A09005_007  PCT_SE_A09005_008  \
# 0                0.0               0.00               1.04               5.09
# 1                0.0               0.58               2.10               3.83
# 2                0.0               3.29               1.19               3.83
# 3                0.0               0.00               1.52               4.96
# 4                0.0               0.00               0.00               9.31
#
#    SE_A09001_001  SE_A09001_002  SE_A09001_003  SE_A09001_004  SE_A09001_005  \
# 0           1927           1829            106            144            540
# 1           1907           1834             21             58            287
# 2           2770           2664            302            530            485
# 3           1513           1438             79            324            277
# 4           2041           1851             50            288            441
#
#    SE_A09001_006  SE_A09001_007  SE_A09001_008  SE_A09001_009  SE_A09001_010  \
# 0            484            261            212             82             98
# 1            460            669            222            117             73
# 2            735            342            221             49            106
# 3            341            269            118             30             75
# 4            392            325            243            112            190
#
#    PCT_SE_A09001_002  PCT_SE_A09001_003  PCT_SE_A09001_004  PCT_SE_A09001_005  \
# 0              94.91               5.50               7.47              28.02
# 1              96.17               1.10               3.04              15.05
# 2              96.17              10.90              19.13              17.51
# 3              95.04               5.22              21.41              18.31
# 4              90.69               2.45              14.11              21.61
#
#    PCT_SE_A09001_006  PCT_SE_A09001_007  PCT_SE_A09001_008  PCT_SE_A09001_009  \
# 0              25.12              13.54              11.00               4.26
# 1              24.12              35.08              11.64               6.14
# 2              26.53              12.35               7.98               1.77
# 3              22.54              17.78               7.80               1.98
# 4              19.21              15.92              11.91               5.49
#
#    PCT_SE_A09001_010
# 0               5.09
# 1               3.83
# 2               3.83
# 3               4.96
# 4               9.31

# %% [markdown]
# <div class="alert alert-info">
#     <b>Overwriting default display settings</b>
#
# By default, pandas outputs the first 10 and last 10 columns. If we want to see the entire table, we can override the defaults. Use with caution!
# </div>

# %%
# I want to see all the data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# Now that we have overridden the default limitations, let's look at a sample row.

# %%
df.sample()
# Out:
#         Geo_FIPS           Geo_GEOID            Geo_NAME  \
# 3092  6073008344  14000US06073008344  Census Tract 83.44
#
#                                              Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 3092  Census Tract 83.44, San Diego County, California         ca         140
#
#       Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 3092            0      ACSSF          8520     NaN         NaN           NaN
#
#       Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_PLACESE  \
# 3092          NaN          6          73         NaN        NaN          NaN
#
#       Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  \
# 3092       8344         NaN         NaN         NaN           NaN
#
#       Geo_AIHHTLI  Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  Geo_CSA  \
# 3092          NaN         NaN       NaN       NaN       NaN      NaN
#
#       Geo_METDIV  Geo_MACC  Geo_MEMI  Geo_NECTA  Geo_CNECTA  Geo_NECTADIV  \
# 3092         NaN       NaN       NaN        NaN         NaN           NaN
#
#       Geo_UA  Geo_UACP  Geo_CDCURR  Geo_SLDU  Geo_SLDL  Geo_VTD  Geo_ZCTA3  \
# 3092     NaN       NaN         NaN       NaN       NaN      NaN        NaN
#
#       Geo_ZCTA5  Geo_SUBMCD  Geo_SDELM  Geo_SDSEC  Geo_SDUNI  Geo_UR  Geo_PCI  \
# 3092        NaN         NaN        NaN        NaN        NaN     NaN      NaN
#
#       Geo_TAZ  Geo_UGA  Geo_BTTR  Geo_BTBG  Geo_PUMA5  Geo_PUMA1  \
# 3092      NaN      NaN       NaN       NaN        NaN        NaN
#
#       SE_A00001_001  SE_A03001_001  SE_A03001_002  SE_A03001_003  \
# 3092           3598           3598           2693            100
#
#       SE_A03001_004  SE_A03001_005  SE_A03001_006  SE_A03001_007  \
# 3092             31            580             16             50
#
#       SE_A03001_008  PCT_SE_A03001_002  PCT_SE_A03001_003  PCT_SE_A03001_004  \
# 3092            128              74.85               2.78               0.86
#
#       PCT_SE_A03001_005  PCT_SE_A03001_006  PCT_SE_A03001_007  \
# 3092              16.12               0.44               1.39
#
#       PCT_SE_A03001_008  SE_A12001_001  SE_A12001_002  SE_A12001_003  \
# 3092               3.56           2613             79            215
#
#       SE_A12001_004  SE_A12001_005  SE_A12001_006  SE_A12001_007  \
# 3092            696            972            362             92
#
#       SE_A12001_008  PCT_SE_A12001_002  PCT_SE_A12001_003  PCT_SE_A12001_004  \
# 3092            197               3.02               8.23              26.64
#
#       PCT_SE_A12001_005  PCT_SE_A12001_006  PCT_SE_A12001_007  \
# 3092               37.2              13.85               3.52
#
#       PCT_SE_A12001_008  SE_A12002_001  SE_A12002_002  SE_A12002_003  \
# 3092               7.54           2613             79           2534
#
#       SE_A12002_004  SE_A12002_005  SE_A12002_006  SE_A12002_007  \
# 3092           2319           1623            651            289
#
#       SE_A12002_008  PCT_SE_A12002_002  PCT_SE_A12002_003  PCT_SE_A12002_004  \
# 3092            197               3.02              96.98              88.75
#
#       PCT_SE_A12002_005  PCT_SE_A12002_006  PCT_SE_A12002_007  \
# 3092              62.11              24.91              11.06
#
#       PCT_SE_A12002_008  SE_A14006_001  SE_A09005_001  SE_A09005_002  \
# 3092               7.54       107917.0           1759           1418
#
#       SE_A09005_009  SE_A09005_010  SE_A09005_003  SE_A09005_004  \
# 3092           1283            135             49              8
#
#       SE_A09005_005  SE_A09005_006  SE_A09005_007  SE_A09005_008  \
# 3092             27              0             19            238
#
#       PCT_SE_A09005_002  PCT_SE_A09005_009  PCT_SE_A09005_010  \
# 3092              80.61              72.94               7.67
#
#       PCT_SE_A09005_003  PCT_SE_A09005_004  PCT_SE_A09005_005  \
# 3092               2.79               0.45               1.53
#
#       PCT_SE_A09005_006  PCT_SE_A09005_007  PCT_SE_A09005_008  SE_A09001_001  \
# 3092                0.0               1.08              13.53           1759
#
#       SE_A09001_002  SE_A09001_003  SE_A09001_004  SE_A09001_005  \
# 3092           1521             98            702            475
#
#       SE_A09001_006  SE_A09001_007  SE_A09001_008  SE_A09001_009  \
# 3092            153             39             26             28
#
#       SE_A09001_010  PCT_SE_A09001_002  PCT_SE_A09001_003  PCT_SE_A09001_004  \
# 3092            238              86.47               5.57              39.91
#
#       PCT_SE_A09001_005  PCT_SE_A09001_006  PCT_SE_A09001_007  \
# 3092               27.0                8.7               2.22
#
#       PCT_SE_A09001_008  PCT_SE_A09001_009  PCT_SE_A09001_010
# 3092               1.48               1.59              13.53

# %% [markdown]
# ## Data types
#
# To get the data types, we will use `.info()`. Notice the new arguments within: `verbose=True, null_counts=True`. This is necessary because our data has so many columns.

# %%
# look at the data types
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3754 entries, 0 to 3753
# Data columns (total 140 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           3754 non-null   int64
#  1   Geo_GEOID          3754 non-null   object
#  2   Geo_NAME           3754 non-null   object
#  3   Geo_QName          3754 non-null   object
#  4   Geo_STUSAB         3754 non-null   object
#  5   Geo_SUMLEV         3754 non-null   int64
#  6   Geo_GEOCOMP        3754 non-null   int64
#  7   Geo_FILEID         3754 non-null   object
#  8   Geo_LOGRECNO       3754 non-null   int64
#  9   Geo_US             0 non-null      float64
#  10  Geo_REGION         0 non-null      float64
#  11  Geo_DIVISION       0 non-null      float64
#  12  Geo_STATECE        0 non-null      float64
#  13  Geo_STATE          3754 non-null   int64
#  14  Geo_COUNTY         3754 non-null   int64
#  15  Geo_COUSUB         0 non-null      float64
#  16  Geo_PLACE          0 non-null      float64
#  17  Geo_PLACESE        0 non-null      float64
#  18  Geo_TRACT          3754 non-null   int64
#  19  Geo_BLKGRP         0 non-null      float64
#  20  Geo_CONCIT         0 non-null      float64
#  21  Geo_AIANHH         0 non-null      float64
#  22  Geo_AIANHHFP       0 non-null      float64
#  23  Geo_AIHHTLI        0 non-null      float64
#  24  Geo_AITSCE         0 non-null      float64
#  25  Geo_AITS           0 non-null      float64
#  26  Geo_ANRC           0 non-null      float64
#  27  Geo_CBSA           0 non-null      float64
#  28  Geo_CSA            0 non-null      float64
#  29  Geo_METDIV         0 non-null      float64
#  30  Geo_MACC           0 non-null      float64
#  31  Geo_MEMI           0 non-null      float64
#  32  Geo_NECTA          0 non-null      float64
#  33  Geo_CNECTA         0 non-null      float64
#  34  Geo_NECTADIV       0 non-null      float64
#  35  Geo_UA             0 non-null      float64
#  36  Geo_UACP           0 non-null      float64
#  37  Geo_CDCURR         0 non-null      float64
#  38  Geo_SLDU           0 non-null      float64
#  39  Geo_SLDL           0 non-null      float64
#  40  Geo_VTD            0 non-null      float64
#  104 SE_A09005_009      3754 non-null   int64
#  105 SE_A09005_010      3754 non-null   int64
#  106 SE_A09005_003      3754 non-null   int64
#  107 SE_A09005_004      3754 non-null   int64
#  108 SE_A09005_005      3754 non-null   int64
#  109 SE_A09005_006      3754 non-null   int64
#  110 SE_A09005_007      3754 non-null   int64
#  111 SE_A09005_008      3754 non-null   int64
#  112 PCT_SE_A09005_002  3725 non-null   float64
#  113 PCT_SE_A09005_009  3725 non-null   float64
#  114 PCT_SE_A09005_010  3725 non-null   float64
#  115 PCT_SE_A09005_003  3725 non-null   float64
#  116 PCT_SE_A09005_004  3725 non-null   float64
#  117 PCT_SE_A09005_005  3725 non-null   float64
#  118 PCT_SE_A09005_006  3725 non-null   float64
#  119 PCT_SE_A09005_007  3725 non-null   float64
#  120 PCT_SE_A09005_008  3725 non-null   float64
#  121 SE_A09001_001      3754 non-null   int64
#  122 SE_A09001_002      3754 non-null   int64
#  123 SE_A09001_003      3754 non-null   int64
#  124 SE_A09001_004      3754 non-null   int64
#  125 SE_A09001_005      3754 non-null   int64
#  126 SE_A09001_006      3754 non-null   int64
#  127 SE_A09001_007      3754 non-null   int64
#  128 SE_A09001_008      3754 non-null   int64
#  129 SE_A09001_009      3754 non-null   int64
#  130 SE_A09001_010      3754 non-null   int64
#  131 PCT_SE_A09001_002  3725 non-null   float64
#  132 PCT_SE_A09001_003  3725 non-null   float64
#  133 PCT_SE_A09001_004  3725 non-null   float64
#  134 PCT_SE_A09001_005  3725 non-null   float64
#  135 PCT_SE_A09001_006  3725 non-null   float64
#  136 PCT_SE_A09001_007  3725 non-null   float64
#  137 PCT_SE_A09001_008  3725 non-null   float64
#  138 PCT_SE_A09001_009  3725 non-null   float64
#  139 PCT_SE_A09001_010  3725 non-null   float64
# dtypes: float64(83), int64(52), object(5)
# memory usage: 4.0+ MB

# %% [markdown]
# ## Assigning data types on import
#
# Let's take a closer look at the column that will become our unique identifier, `Geo_FIPS`.

# %%
df.Geo_FIPS.head()
# Out:
# 0    6037101110
# 1    6037101122
# 2    6037101210
# 3    6037101220
# 4    6037101300
# Name: Geo_FIPS, dtype: int64

# %% [markdown]
# ### The leading zero dilemma...
# Waaaaaiiit... what happened to the leading "0" in the `Geo_FIPS` code? And for that matter, the `geo_STATE` and `geo_COUNTY` columns?

# %%
# do it yourself. output a sample set for the geo_STATE and geo_COUNTY columns

# %% [markdown]
# ### The FIPS code
# But what is a FIPS code and why is it important?
#
# ![fips code](https://learn.arcgis.com/en/related-concepts/GUID-D7AA4FD1-E7FE-49D7-9D11-07915C9ACC68-web.png)
#
# [Source: ESRI](https://learn.arcgis.com/en/related-concepts/united-states-census-geography.htm)

# %% [markdown]
# That's right, python automatically makes decisions on import, and interprets "FIPS" as an integer column (after all, it's all numbers aren't they), thus cropping the leading zeroes. But no, that [leading zero](https://en.wikipedia.org/wiki/Leading_zero) is extremely important, as `06` represents the state of California, and `037` represents LA County.
#
# Let's fix this by re-importing the data, this time, specifying the `FIPS` columns as a string:

# %%
df = pd.read_csv(
    '../../data/se_ca.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
df.head()
# Out:
#       Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  06037101110  14000US06037101110  Census Tract 1011.10
# 1  06037101122  14000US06037101122  Census Tract 1011.22
# 2  06037101210  14000US06037101210  Census Tract 1012.10
# 3  06037101220  14000US06037101220  Census Tract 1012.20
# 4  06037101300  14000US06037101300     Census Tract 1013
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1011.22, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1012.10, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1012.20, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1013, Los Angeles County, California         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 0            0      ACSSF          3870     NaN         NaN           NaN
# 1            0      ACSSF          3871     NaN         NaN           NaN
# 2            0      ACSSF          3872     NaN         NaN           NaN
# 3            0      ACSSF          3873     NaN         NaN           NaN
# 4            0      ACSSF          3874     NaN         NaN           NaN
#
#    Geo_STATECE Geo_STATE Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_PLACESE  \
# 0          NaN        06        037         NaN        NaN          NaN
# 1          NaN        06        037         NaN        NaN          NaN
# 2          NaN        06        037         NaN        NaN          NaN
# 3          NaN        06        037         NaN        NaN          NaN
# 4          NaN        06        037         NaN        NaN          NaN
#
#    Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  Geo_AIHHTLI  \
# 0     101110         NaN         NaN         NaN           NaN          NaN
# 1     101122         NaN         NaN         NaN           NaN          NaN
# 2     101210         NaN         NaN         NaN           NaN          NaN
# 3     101220         NaN         NaN         NaN           NaN          NaN
# 4     101300         NaN         NaN         NaN           NaN          NaN
#
#    Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  Geo_CSA  Geo_METDIV  Geo_MACC  \
# 0         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 1         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 2         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 3         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 4         NaN       NaN       NaN       NaN      NaN         NaN       NaN
#
#    Geo_MEMI  Geo_NECTA  Geo_CNECTA  Geo_NECTADIV  Geo_UA  Geo_UACP  \
# 0       NaN        NaN         NaN           NaN     NaN       NaN
# 1       NaN        NaN         NaN           NaN     NaN       NaN
# 2       NaN        NaN         NaN           NaN     NaN       NaN
# 3       NaN        NaN         NaN           NaN     NaN       NaN
# 4       NaN        NaN         NaN           NaN     NaN       NaN
#
#    Geo_CDCURR  Geo_SLDU  Geo_SLDL  Geo_VTD  Geo_ZCTA3  Geo_ZCTA5  Geo_SUBMCD  \
# 0         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 1         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 2         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 3         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 4         NaN       NaN       NaN      NaN        NaN        NaN         NaN
#
#    Geo_SDELM  Geo_SDSEC  Geo_SDUNI  Geo_UR  Geo_PCI  Geo_TAZ  Geo_UGA  \
# 0        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 1        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 2        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 3        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 4        NaN        NaN        NaN     NaN      NaN      NaN      NaN
#
#    Geo_BTTR  Geo_BTBG  Geo_PUMA5  Geo_PUMA1  SE_A00001_001  SE_A03001_001  \
# 0       NaN       NaN        NaN        NaN           4314           4314
# 1       NaN       NaN        NaN        NaN           3239           3239
# 2       NaN       NaN        NaN        NaN           6052           6052
# 3       NaN       NaN        NaN        NaN           3497           3497
# 4       NaN       NaN        NaN        NaN           4297           4297
#
#    SE_A03001_002  SE_A03001_003  SE_A03001_004  SE_A03001_005  SE_A03001_006  \
# 0           3314             47              4            329              4
# 1           2837             61             13            206              0
# 2           4771            172              0            260              0
# 3           2494             71              0            302              0
# 4           3705            161              0            289              0
#
#    SE_A03001_007  SE_A03001_008  PCT_SE_A03001_002  PCT_SE_A03001_003  \
# 0            499            117              76.82               1.09
# 1             61             61              87.59               1.88
# 2            736            113              78.83               2.84
# 3            487            143              71.32               2.03
# 4             48             94              86.22               3.75
#
#    PCT_SE_A03001_004  PCT_SE_A03001_005  PCT_SE_A03001_006  PCT_SE_A03001_007  \
# 0               0.09               7.63               0.09              11.57
# 1               0.40               6.36               0.00               1.88
# 2               0.00               4.30               0.00              12.16
# 3               0.00               8.64               0.00              13.93
# 4               0.00               6.73               0.00               1.12
#
#    PCT_SE_A03001_008  SE_A12001_001  SE_A12001_002  SE_A12001_003  \
# 0               2.71           3085            524            765
# 1               1.88           2597            168            749
# 2               1.87           4107            762           1185
# 3               4.09           2484            515            700
# 4               2.19           3446            362            949
#
#    SE_A12001_004  SE_A12001_005  SE_A12001_006  SE_A12001_007  SE_A12001_008  \
# 0           1101            411            180             50             54
# 1            888            463            248             13             68
# 2           1340            548            174             36             62
# 3            769            347            129              0             24
# 4           1145            604            278             82             26
#
#    PCT_SE_A12001_002  PCT_SE_A12001_003  PCT_SE_A12001_004  PCT_SE_A12001_005  \
# 0              16.99              24.80              35.69              13.32
# 1               6.47              28.84              34.19              17.83
# 2              18.55              28.85              32.63              13.34
# 3              20.73              28.18              30.96              13.97
# 4              10.50              27.54              33.23              17.53
#
#    PCT_SE_A12001_006  PCT_SE_A12001_007  PCT_SE_A12001_008  SE_A12002_001  \
# 0               5.83               1.62               1.75           3085
# 1               9.55               0.50               2.62           2597
# 2               4.24               0.88               1.51           4107
# 3               5.19               0.00               0.97           2484
# 4               8.07               2.38               0.75           3446
#
#    SE_A12002_002  SE_A12002_003  SE_A12002_004  SE_A12002_005  SE_A12002_006  \
# 0            524           2561           1796            695            284
# 1            168           2429           1680            792            329
# 2            762           3345           2160            820            272
# 3            515           1969           1269            500            153
# 4            362           3084           2135            990            386
#
#    SE_A12002_007  SE_A12002_008  PCT_SE_A12002_002  PCT_SE_A12002_003  \
# 0            104             54              16.99              83.01
# 1             81             68               6.47              93.53
# 2             98             62              18.55              81.45
# 3             24             24              20.73              79.27
# 4            108             26              10.50              89.50
#
#    PCT_SE_A12002_004  PCT_SE_A12002_005  PCT_SE_A12002_006  PCT_SE_A12002_007  \
# 0              58.22              22.53               9.21               3.37
# 1              64.69              30.50              12.67               3.12
# 2              52.59              19.97               6.62               2.39
# 3              51.09              20.13               6.16               0.97
# 4              61.96              28.73              11.20               3.13
#
#    PCT_SE_A12002_008  SE_A14006_001  SE_A09005_001  SE_A09005_002  \
# 0               1.75        53077.0           1927           1763
# 1               2.62        88953.0           1907           1776
# 2               1.51        32119.0           2770           2445
# 3               0.97        41728.0           1513           1360
# 4               0.75        86914.0           2041           1765
#
#    SE_A09005_009  SE_A09005_010  SE_A09005_003  SE_A09005_004  SE_A09005_005  \
# 0           1588            175             46              0              0
# 1           1645            131              7              0              0
# 2           2235            210             95              0              0
# 3           1235            125             55              0              0
# 4           1631            134             86              0              0
#
#    SE_A09005_006  SE_A09005_007  SE_A09005_008  PCT_SE_A09005_002  \
# 0              0             20             98              91.49
# 1             11             40             73              93.13
# 2             91             33            106              88.27
# 3              0             23             75              89.89
# 4              0              0            190              86.48
#
#    PCT_SE_A09005_009  PCT_SE_A09005_010  PCT_SE_A09005_003  PCT_SE_A09005_004  \
# 0              82.41               9.08               2.39                0.0
# 1              86.26               6.87               0.37                0.0
# 2              80.69               7.58               3.43                0.0
# 3              81.63               8.26               3.64                0.0
# 4              79.91               6.57               4.21                0.0
#
#    PCT_SE_A09005_005  PCT_SE_A09005_006  PCT_SE_A09005_007  PCT_SE_A09005_008  \
# 0                0.0               0.00               1.04               5.09
# 1                0.0               0.58               2.10               3.83
# 2                0.0               3.29               1.19               3.83
# 3                0.0               0.00               1.52               4.96
# 4                0.0               0.00               0.00               9.31
#
#    SE_A09001_001  SE_A09001_002  SE_A09001_003  SE_A09001_004  SE_A09001_005  \
# 0           1927           1829            106            144            540
# 1           1907           1834             21             58            287
# 2           2770           2664            302            530            485
# 3           1513           1438             79            324            277
# 4           2041           1851             50            288            441
#
#    SE_A09001_006  SE_A09001_007  SE_A09001_008  SE_A09001_009  SE_A09001_010  \
# 0            484            261            212             82             98
# 1            460            669            222            117             73
# 2            735            342            221             49            106
# 3            341            269            118             30             75
# 4            392            325            243            112            190
#
#    PCT_SE_A09001_002  PCT_SE_A09001_003  PCT_SE_A09001_004  PCT_SE_A09001_005  \
# 0              94.91               5.50               7.47              28.02
# 1              96.17               1.10               3.04              15.05
# 2              96.17              10.90              19.13              17.51
# 3              95.04               5.22              21.41              18.31
# 4              90.69               2.45              14.11              21.61
#
#    PCT_SE_A09001_006  PCT_SE_A09001_007  PCT_SE_A09001_008  PCT_SE_A09001_009  \
# 0              25.12              13.54              11.00               4.26
# 1              24.12              35.08              11.64               6.14
# 2              26.53              12.35               7.98               1.77
# 3              22.54              17.78               7.80               1.98
# 4              19.21              15.92              11.91               5.49
#
#    PCT_SE_A09001_010
# 0               5.09
# 1               3.83
# 2               3.83
# 3               4.96
# 4               9.31

# %% [markdown]
# Confirm that your new dataframe has the correct datatypes.

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3754 entries, 0 to 3753
# Data columns (total 140 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   
#  128 SE_A09001_008      3754 non-null   int64
#  129 SE_A09001_009      3754 non-null   int64
#  130 SE_A09001_010      3754 non-null   int64
#  131 PCT_SE_A09001_002  3725 non-null   float64
#  132 PCT_SE_A09001_003  3725 non-null   float64
#  133 PCT_SE_A09001_004  3725 non-null   float64
#  134 PCT_SE_A09001_005  3725 non-null   float64
#  135 PCT_SE_A09001_006  3725 non-null   float64
#  136 PCT_SE_A09001_007  3725 non-null   float64
#  137 PCT_SE_A09001_008  3725 non-null   float64
#  138 PCT_SE_A09001_009  3725 non-null   float64
#  139 PCT_SE_A09001_010  3725 non-null   float64
# dtypes: float64(83), int64(49), object(8)
# memory usage: 4.0+ MB

# %% [markdown]
# <div class="alert alert-danger">
#
# The [leading zero dilemma](https://en.wikipedia.org/wiki/Leading_zero) is a known enigma in GIS and data integration. Even ESRI has yet to find a clean solution to this problem, forcing users into resorting to [weird hacks](https://support.esri.com/en/technical-article/000013035) to circumvent this problem. Python and pandas actually gives us a "clean-ish" solution that makes logical sense... doesn't it?

# %% [markdown]
# ## Getting a list of column names
#
# Now let's investigate what this enormous dataset looks like. More than 100 columns?

# %%
# output the columns
df.columns
# Out:
# Index(['Geo_FIPS', 'Geo_GEOID', 'Geo_NAME', 'Geo_QName', 'Geo_STUSAB',
#        'Geo_SUMLEV', 'Geo_GEOCOMP', 'Geo_FILEID', 'Geo_LOGRECNO', 'Geo_US',
#        ...
#        'SE_A09001_010', 'PCT_SE_A09001_002', 'PCT_SE_A09001_003',
#        'PCT_SE_A09001_004', 'PCT_SE_A09001_005', 'PCT_SE_A09001_006',
#        'PCT_SE_A09001_007', 'PCT_SE_A09001_008', 'PCT_SE_A09001_009',
#        'PCT_SE_A09001_010'],
#       dtype='object', length=140)

# %%
# if there are too many, try outputting as a list:
list(df) # this is the same as df.columns.to_list()
# Out:
# ['Geo_FIPS',
#  'Geo_GEOID',
#  'Geo_NAME',
#  'Geo_QName',
#  'Geo_STUSAB',
#  'Geo_SUMLEV',
#  'Geo_GEOCOMP',
#  'Geo_FILEID',
#  'Geo_LOGRECNO',
#  'Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_STATE',
#  'Geo_COUNTY',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_TRACT',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PUMA5',
#  'Geo_PUMA1',
#  'SE_A00001_001',
#  'SE_A03001_001',
#  'SE_A03001_002',
#  'SE_A03001_003',
#  'SE_A03001_004',
#  'SE_A03001_005',
#  'SE_A03001_006',
#  'SE_A03001_007',
#  'SE_A03001_008',
#  'PCT_SE_A03001_002',
#  'PCT_SE_A03001_003',
#  'PCT_SE_A03001_004',
#  'PCT_SE_A03001_005',
#  'PCT_SE_A03001_006',
#  'PCT_SE_A03001_007',
#  'PCT_SE_A03001_008',
#  'SE_A12001_001',
#  'SE_A12001_002',
#  'SE_A12001_003',
#  'SE_A12001_004',
#  'SE_A12001_005',
#  'SE_A12001_006',
#  'SE_A12001_007',
#  'SE_A12001_008',
#  'PCT_SE_A12001_002',
#  'PCT_SE_A12001_003',
#  'PCT_SE_A12001_004',
#  'PCT_SE_A12001_005',
#  'PCT_SE_A12001_006',
#  'PCT_SE_A12001_007',
#  'PCT_SE_A12001_008',
#  'SE_A12002_001',
#  'SE_A12002_002',
#  'SE_A12002_003',
#  'SE_A12002_004',
#  'SE_A12002_005',
#  'SE_A12002_006',
#  'SE_A12002_007',
#  'SE_A12002_008',
#  'PCT_SE_A12002_002',
#  'PCT_SE_A12002_003',
#  'PCT_SE_A12002_004',
#  'PCT_SE_A12002_005',
#  'PCT_SE_A12002_006',
#  'PCT_SE_A12002_007',
#  'PCT_SE_A12002_008',
#  'SE_A14006_001',
#  'SE_A09005_001',
#  'SE_A09005_002',
#  'SE_A09005_009',
#  'SE_A09005_010',
#  'SE_A09005_003',
#  'SE_A09005_004',
#  'SE_A09005_005',
#  'SE_A09005_006',
#  'SE_A09005_007',
#  'SE_A09005_008',
#  'PCT_SE_A09005_002',
#  'PCT_SE_A09005_009',
#  'PCT_SE_A09005_010',
#  'PCT_SE_A09005_003',
#  'PCT_SE_A09005_004',
#  'PCT_SE_A09005_005',
#  'PCT_SE_A09005_006',
#  'PCT_SE_A09005_007',
#  'PCT_SE_A09005_008',
#  'SE_A09001_001',
#  'SE_A09001_002',
#  'SE_A09001_003',
#  'SE_A09001_004',
#  'SE_A09001_005',
#  'SE_A09001_006',
#  'SE_A09001_007',
#  'SE_A09001_008',
#  'SE_A09001_009',
#  'SE_A09001_010',
#  'PCT_SE_A09001_002',
#  'PCT_SE_A09001_003',
#  'PCT_SE_A09001_004',
#  'PCT_SE_A09001_005',
#  'PCT_SE_A09001_006',
#  'PCT_SE_A09001_007',
#  'PCT_SE_A09001_008',
#  'PCT_SE_A09001_009',
#  'PCT_SE_A09001_010']

# %% [markdown]
# What are these columns?
#
#
# | Variables | Description |
# |:---|:---|
# | FIPS:|           FIPS |
# | GEOID:|          Geographic Identifier |
# | NAME:|           Name of Area |
# | QName:|          Qualifying Name |
# | STUSAB:|         State/U.S.-Abbreviation (USPS) |
# | SUMLEV:|         Summary Level |
# | GEOCOMP:|        Geographic Component |
# | FILEID:|         File Identification |
# | LOGRECNO:|       Logical Record Number |
# | US:|             US |
# | REGION:|         Region |
# | DIVISION:|       Division |
# | STATECE:|        State (Census Code) |
# | STATE:|          State (FIPS) |
# | COUNTY:|         County |
# | COUSUB:|         County Subdivision (FIPS) |
# | PLACE:|          Place (FIPS Code) |
# | PLACESE:|        Place (State FIPS + Place FIPS) |
# | TRACT:|          Census Tract |
# | BLKGRP:|         Block Group |
# | CONCIT:|         Consolidated City |
# | AIANHH:|         American Indian Area/Alaska Native Area/Hawaiian Home Land (Census) |
# | AIANHHFP:|       American Indian Area/Alaska Native Area/Hawaiian Home Land (FIPS) |
# | AIHHTLI:|        American Indian Trust Land/Hawaiian Home Land Indicator |
# | AITSCE:|         American Indian Tribal Subdivision (Census) |
# | AITS:|           American Indian Tribal Subdivision (FIPS) |
# | ANRC:|           Alaska Native Regional Corporation (FIPS) |
# | CBSA:|           Metropolitan and Micropolitan Statistical Area |
# | CSA:|            Combined Statistical Area |
# | METDIV:|         Metropolitan Division |
# | MACC:|           Metropolitan Area Central City |
# | MEMI:|           Metropolitan/Micropolitan Indicator Flag |
# | NECTA:|          New England City and Town Combined Statistical Area |
# | CNECTA:|         New England City and Town Area |
# | NECTADIV:|       New England City and Town Area Division |
# | UA:|             Urban Area |
# | UACP:|           Urban Area Central Place |
# | CDCURR:|         Current Congressional District *** |
# | SLDU:|           State Legislative District Upper |
# | SLDL:|           State Legislative District Lower |
# | VTD:|            Voting District |
# | ZCTA3:|          ZIP Code Tabulation Area (3-digit) |
# | ZCTA5:|          ZIP Code Tabulation Area (5-digit) |
# | SUBMCD:|         Subbarrio (FIPS) |
# | SDELM:|          School District (Elementary) |
# | SDSEC:|          School District (Secondary) |
# | SDUNI:|          School District (Unified) |
# | UR:|             Urban/Rural |
# | PCI:|            Principal City Indicator |
# | TAZ:|            Traffic Analysis Zone |
# | UGA:|            Urban Growth Area |
# | BTTR:|           Tribal Tract |
# | BTBG:|           Tribal Block Group |
# | PUMA5:|          Public Use Microdata Area - 5% File |
# | PUMA1:|          Public Use Microdata Area - 1% File |
# | A00001_001:|     Total Population |
# | A03001_001:|     Total Population: |
# | A03001_002:|     Total Population: White Alone |
# | A03001_003:|     Total Population: Black or African American Alone |
# | A03001_004:|     Total Population: American Indian and Alaska Native Alone |
# | A03001_005:|     Total Population: Asian Alone |
# | A03001_006:|     Total Population: Native Hawaiian and Other Pacific Islander Alone |
# | A03001_007:|     Total Population: Some Other Race Alone |
# | A03001_008:|     Total Population: Two or More Races |
# | PCT_A03001_002:| % Total Population: White Alone |
# | PCT_A03001_003:| % Total Population: Black or African American Alone |
# | PCT_A03001_004:| % Total Population: American Indian and Alaska Native Alone |
# | PCT_A03001_005:| % Total Population: Asian Alone |
# | PCT_A03001_006:| % Total Population: Native Hawaiian and Other Pacific Islander Alone |
# | PCT_A03001_007:| % Total Population: Some Other Race Alone |
# | PCT_A03001_008:| % Total Population: Two or More Races |
# | A12001_001:|     Population 25 Years and Over: |
# | A12001_002:|     Population 25 Years and Over: Less than High School |
# | A12001_003:|     Population 25 Years and Over: High School Graduate (Includes Equivalency) |
# | A12001_004:|     Population 25 Years and Over: Some College |
# | A12001_005:|     Population 25 Years and Over: Bachelor's Degree |
# | A12001_006:|     Population 25 Years and Over: Master's Degree |
# | A12001_007:|     Population 25 Years and Over: Professional School Degree |
# | A12001_008:|     Population 25 Years and Over: Doctorate Degree |
# | PCT_A12001_002:| % Population 25 Years and Over: Less than High School |
# | PCT_A12001_003:| % Population 25 Years and Over: High School Graduate (Includes Equivalency) |
# | PCT_A12001_004:| % Population 25 Years and Over: Some College |
# | PCT_A12001_005:| % Population 25 Years and Over: Bachelor's Degree |
# | PCT_A12001_006:| % Population 25 Years and Over: Master's Degree |
# | A09001_009:|     Workers 16 Years and Over: Did Not Work At Home: 90 or More Minutes |
# | A09001_010:|     Workers 16 Years and Over: Worked At Home |
# | PCT_A09001_002:| % Workers 16 Years and Over: Did Not Work At Home |
# | PCT_A09001_003:| % Workers 16 Years and Over: Did Not Work At Home: Less than 10 Minutes |
# | PCT_A09001_004:| % Workers 16 Years and Over: Did Not Work At Home: 10 to 19 Minutes |
# | PCT_A09001_005:| % Workers 16 Years and Over: Did Not Work At Home: 20 to 29 Minutes |
# | PCT_A09001_006:| % Workers 16 Years and Over: Did Not Work At Home: 30 to 39 Minutes |
# | PCT_A09001_007:| % Workers 16 Years and Over: Did Not Work At Home: 40 to 59 Minutes |
# | PCT_A09001_008:| % Workers 16 Years and Over: Did Not Work At Home: 60 to 89 Minutes |
# | PCT_A09001_009:| % Workers 16 Years and Over: Did Not Work At Home: 90 or More Minutes |
# | PCT_A09001_010:| % Workers 16 Years and Over: Worked At Home      || |

# %% [markdown]
# # Add Subsetting here

# %% [markdown]
# ## Simple stats and plots

# %%
# access a single column like df['col_name']
# SE_A00001_001 is the variable for Total Population
df['SE_A00001_001'].head()

# %%
# What is the mean?
df['SE_A00001_001'].mean()

# %%
# get some stats
df['SE_A00001_001'].describe()

# %%
df['SE_A00001_001'].plot.hist(bins=50)

# %% [markdown]
# <div class="alert alert-info">
#     Now it's your turn. Find some stats for different fields in the data and output them below.
#     </div>

# %% [markdown]
# ## Getting unique or distinct values in a column
# The data contains rows for several counties. What are they?

# %%
df['Geo_COUNTY'].unique()

# %% [markdown]
# ## Replacing values, creating new columns

# %% [markdown]
# We can replace the current values ('037', '059', etc) to something more human friendly. First create a lookup dict/object with key/value pairs that match the data:

# %%
# dict that maps state fips code -> state name
county_fips_lookup = {
    '037' : 'Los Angeles',
    '059' : 'Orange',
    '073' : 'San Diego',
    '075' : 'San Francisco'
}

# %% [markdown]
# Next, use the `.replace()` function to batch and replace the values in the data. Notice, however, that rather than replacing the same column (which you can do but would not preserve the FIPS codes), you can specify a new columns and call it `County`:

# %%
# replace fips code with state name with the replace() method
df['County'] = df['Geo_COUNTY'].replace(county_fips_lookup)
df.sample(5)

# %% [markdown]
# <div class="alert alert-info">
#     Now it's your turn. Create a new column `State` that is simply `California`.
# </div>

# %% [markdown]
# ## Displaying null/missing values
# Null values, or empty values, can be problematic in many ways. It is always good practice to scrutinize your data for missing values, and to identify where they are and why. The following arguments are simple calls to the data to find where these null values are.

# %%
# first double check how many rows we have
len(df)

# %%
# null values in the data for a single column
df.Geo_FIPS.isna().sum()

# %%
# same thing in a different notation
df['Geo_FIPS'].isna().sum()

# %%
# null values in the data for a all columns
df.isna().sum()

# %%
# show rows with null columns
# PCT_SE_A12001_008 is percent with PhD
df[df['PCT_SE_A12001_008'].isnull()]

# %% [markdown]
# Why do these rows have null values?

# %% [markdown]
# ## Sorting
# What are the top 10 most populated census tracts? What are the census tracts with the highest hispanic popluation? To answer these questions, the simplest method is to sort the data by their respective columns.

# %%
df_sorted = df.sort_values(by='SE_A00001_001',ascending = False)

# %%
# display the data, but just a few columns to keep it clean
df_sorted[['Geo_QName','SE_A00001_001']].head(10)

# %%
df_sorted.head(10).plot.bar(x='Geo_QName',
                            y='SE_A00001_001')

# %%
# Make it prettier with labels
df_sorted.head(10).plot.bar(x='Geo_QName',
                            y='SE_A00001_001', 
                            label='Total Population', 
                            xlabel='Hello')

# %% [markdown]
# <div class="alert alert-info">
#     Now it's your turn! Create a table and accompanying bar plot for the top 10 values for column of your choice (e.g. Median Household Income).
# </div>

# %% [markdown]
# ## Filtering and subsetting data
# Sorting is one method, but the process of discovery compels us to interrogate the data in different ways. One method of doing so is to query, or filter the data to see specific views of the data based on a question you may have. For example, what are the census tract that have no people in them? Or, Which census tracts are more than 75% black?

# %%
# find where total pop is 0
df['SE_A00001_001']==0

# %% [markdown]
# This returns a boolean (true of false) for every row where the condition you asked for, in this case whether total population is 0, is specified.
#
# That's not very useful.
#
# Instead, we can subset the data with this syntax.

# %%
# now subset the data so that we can see the data per row... 
# in other words, this syntax is asking to "show me the values in my dataframe that match this filter
df[df['SE_A00001_001']==0]

# %% [markdown]
# Note that unless you specify the resulting output as a new variable, the results are only temporary (in memory). If you want to use the results for subsequent analysis, you need to create a new variable.

# %%
# create a new variable for census tracts with zero pop
df_no_pop = df[df['SE_A00001_001']==0]

# how many records?
print('There are ' + str(len(df_no_pop)) + ' census tracts with no people in them')
# display it
df_no_pop[['Geo_QName','SE_A00001_001']]

# %% [markdown]
# <div class="alert alert-info">
#     Now it's your turn! Find out how many census tracts are 75% or more Black, and output them in a table.
#     <br>
#     <br>
#     Extra points if you can show only relevant columns, and sort them from highest to lowest!
# </div>

# %%
df_75plus_black = df[df['PCT_SE_A03001_003']>=75]
df_75plus_black.sort_values(by='PCT_SE_A03001_003', ascending=False)[['Geo_QName','PCT_SE_A03001_003']]

# %%
# What is the average median household income (SE_A14006_001) for the top 10 census tracts
# with the highest percentage of PhDs? PCT_A12001_008
df_phd_sorted = df.sort_values(by='PCT_SE_A12001_008',ascending=False).head(10)
df_phd_sorted[['Geo_QName','PCT_SE_A12001_008','SE_A14006_001']]

# %%
df_phd_sorted.SE_A14006_001.mean()

# %% [markdown]
# ## Combining queries
# All good so far. But what if you wanted to query multiple columns? For example, your question may be, "Which census tracts

# %% [markdown]
# ## Start plotting this data
# - A14006_001: 	Median Household Income (In 2018 Inflation Adjusted Dollars)

# %% [markdown]
# ## Case study: Race analysis

# %% [markdown]
# ### race variables
#        A03001_001:   Total Population:
#             A03001_002:      White Alone
#             A03001_003:      Black or African American Alone
#             A03001_004:      American Indian and Alaska Native Alone
#             A03001_005:      Asian Alone
#             A03001_006:      Native Hawaiian and Other Pacific Islander Alone
#             A03001_007:      Some Other Race Alone
#             A03001_008:      Two or More Races

# %%
import plotly.express as px

# %%
# put them in an list
race_vars = ['Geo_FIPS','County','SE_A03001_002','SE_A03001_003','SE_A03001_004','SE_A03001_005','SE_A03001_006','SE_A03001_007','SE_A03001_008']

# %%
# create a subset
df_race=df[race_vars]
df_race.head()

# %%
# rename columns
race_columns = ['FIPS','County','White','Black','Am_Indian','Asian','Haw_API','Other_Alone','TwoOrMore']
df_race.columns = race_columns
df_race.head(5)

# %% [markdown]
# ## Grouping

# %%
# group them by county
df_race_by_county = df_race.groupby(by=["County"]).sum().reset_index()
df_race_by_county

# %% [markdown]
# We can transpose the data using the melt() function:

# %%
df_race_by_county = pd.melt(df_race_by_county,
               id_vars=['County'],
               var_name="race",
               value_name="count")
df_race_by_county

# %%
type(df_race_by_county.County[0])

# %%
px.bar(df_race_by_county,
       x='County',
       y='count',
       color='race')

# %%
fig = px.histogram(df, x="SE_A14006_001",color="County")
fig.show()

# %%
# df.groupby('County')['Median Household Income (In 2018 Inflation Adjusted Dollars)'].describe().astype(int)
df.groupby('County')['SE_A14006_001'].describe()

# %%
# subset the dataframe into majority white and majority hispanic subsets
df_white = df[df['PCT_SE_A03001_002'] > 50]
df_black = df[df['PCT_SE_A03001_003'] > 50]

# %%
fig = px.scatter(df, x="PCT_SE_A12001_005", y="SE_A14006_001", color="County"
                 )
fig.show()

# %% [markdown]
# # Maps!

# %% [markdown]
# ## Geopandas to read geojson

# %%
import geopandas as gpd

# %%
# tracts=gpd.read_file('https://opendata.arcgis.com/datasets/152f90d3a34a43ef998448281505d45e_0.geojson')
tracts=gpd.read_file('../../data/la_tracts.geojson')
tracts.head()

# %%
tracts.info(verbose=True, null_counts=True)

# %%
# we only really need FIPS and geometry, so let's subset the data
tracts = tracts[['name','geometry']]
tracts.head()

# %%
# rename the columns
tracts.columns = ['FIPS','geometry']

# %%
tracts.head()

# %%
tracts.plot(figsize=(12,10))

# %% [markdown]
# ## Merging/joining data

# %%
tracts2=tracts.merge(df_race,on="FIPS")

# %%
tracts2.head()

# %%
tracts2.plot(figsize=(12,10),column='Black',legend=True, scheme='NaturalBreaks')

# %%
tracts2.plot(figsize=(12,10),column='White',legend=True, scheme='NaturalBreaks')

# %%
tracts2.plot(figsize=(12,10),column='Asian',legend=True, scheme='NaturalBreaks')

# %% [markdown]
# ## Folium

# %%
import folium

# %%
m = folium.Map(location=[34,-118], tiles='CartoDB dark_matter', attribution='CartoDB')
# tracts2.dtypes

# %%
print(tracts2.iloc[0].geometry)

# %%
tracts2.isna().sum()

# %%
m = folium.Map(location=[34,-118], tiles='CartoDB positron', attribution='CartoDB')
# tracts2.dtypes

# plot chorpleth over the base map
folium.Choropleth(
                  geo_data=tracts2,                                # geo data
                  data=tracts2, 
                  key_on='feature.properties.FIPS',# data
#                   key_on='feature.properties.name', # feature.properties.key
                  columns=['FIPS', 'White'],   # [key, value]
                  fill_color='RdPu',                     # cmap
                  line_weight=0.1,                       # line wight (of the border)
                  fill_opacity=0.8,
                  line_opacity=0.8,                      # line opacity (of the border)
                  legend_name='Population White (2014-2018 ACS 5-Year estimates)').add_to(m)    # name on the legend color bar
m
